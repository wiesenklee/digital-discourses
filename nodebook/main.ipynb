# %% [markdown]
# # Discourse Shift based on Keywords

# %% [markdown]
# ## Imports and Helpers

# %%
import math
import os
import re
import requests
import pandas as pd
from youtube_transcript_api import (
    NoTranscriptFound,
    TranscriptsDisabled,
    VideoUnavailable,
    YouTubeTranscriptApi,
    formatters,
)

api_key = ""
api_url_playlist = "https://www.googleapis.com/youtube/v3/playlistItems"


def get_transcript(video_id: str) -> str:
    ytt_api: YouTubeTranscriptApi = YouTubeTranscriptApi()
    try:
        transcript = ytt_api.fetch(video_id, ["de"])
    except (VideoUnavailable, NoTranscriptFound, TranscriptsDisabled):
        print("Failed to get transcript")
        return ""

    txt_formatter = formatters.TextFormatter()
    return txt_formatter.format_transcript(transcript)


def get_video_ids(playlist_id: str, until: str) -> list[tuple[str, str]]:
    until_int = int(until.replace("-", ""))
    request_params = {
        "part": "contentDetails",
        "playlistId": playlist_id,
        "maxResults": 50,
        "key": api_key,
    }
    next_page_token: str | None = None
    playlist_data: list[tuple[str, str]] = []
    print("Starting YouTube-Api requests...")
    print("Request Count: |", end="")
    while True:
        if next_page_token:
            request_params["pageToken"] = next_page_token
        print("-", end="")
        response = requests.get(
            url=api_url_playlist,
            params=request_params,
            timeout=10,
        )
        response.raise_for_status()

        data = response.json()
        items = data.get("items")
        for item in items:
            content = item.get("contentDetails")
            if not content.get("videoPublishedAt"):
                continue
            published_int = int(content["videoPublishedAt"][:10].replace("-", ""))
            if published_int < until_int:
                print("| Finished.")
                return playlist_data
            playlist_data.append(
                (
                    content["videoId"],
                    content["videoPublishedAt"][:10],
                )
            )
        next_page_token = data.get("nextPageToken")
        if not next_page_token:
            break
    print("| Finished.")
    return playlist_data


def save_transcript(transcript: str, date: str, folder: str):
    year = date[:4]
    try:
        os.mkdir(f"../data/{folder}")
    except FileExistsError:
        pass
    try:
        os.mkdir(f"../data/{folder}/{year}")
    except FileExistsError:
        pass
    with open(
        f"../data/{folder}/{year}/{date}.txt", "w", encoding="utf-8"
    ) as text_file:
        _ = text_file.write(transcript)


def save_transcripts(video_ids: list[tuple[str, str]], folder: str):
    for i, data in enumerate(video_ids):
        if i < 0:  # Adjust to where ip-block has quitted last attempt
            continue
        print(data[1] + " " + str(i))
        t = get_transcript(data[0])
        if len(t) > 0:
            save_transcript(get_transcript(data[0]), data[1], folder)
        else:
            print(f"empty transcript for {data[0]}")


def save_data(video_ids: list[tuple[str, str]], data_folder: str):
    data = pd.DataFrame(video_ids, columns=["video_ids", "date"])
    data.drop_duplicates(subset=["date"], inplace=True)
    data["date"] = pd.to_datetime(data["date"])

    for root, dirs, files in os.walk(f"../data/{data_folder}"):
        for name in files:
            if name.endswith(".txt"):
                with open(os.path.join(root, name), "r", encoding="utf-8") as text_file:
                    transcript = text_file.read().replace("\n", " ")
                    data.loc[data["date"] == name[:-4], "transcript"] = transcript

    data["transcript_length"] = data["transcript"].apply(lambda x: len(str(x)))
    data["transcript_words"] = data["transcript"].apply(
        lambda x: len(str(x).split(" "))
    )

    data.to_pickle(f"../data/{data_folder}/{data_folder}.pkl")
    group_data_by_month(data).to_json(f"../data/{data_folder}/{data_folder}.json", orient="table")


def load_from_pickle(data_folder: str) -> pd.DataFrame:
    return pd.read_pickle(f"../data/{data_folder}/{data_folder}.pkl")


def count_keywords(transcript: str, keywords: list[str]) -> int:
    return len(re.findall("|".join(keywords), transcript, re.IGNORECASE))


def group_data_by_month(data: pd.DataFrame):
    data["date_y-m"] = data["date"].apply(lambda x: x.replace(day=1))
    return data.groupby("date_y-m").agg(
        {"transcript": " ".join, "transcript_words": "sum", "transcript_length": "sum"}
    )


def group_data_by_quarter(data: pd.DataFrame):
    data["date_y-q"] = data["date"].apply(
        lambda x: x.replace(day=1, month=(math.ceil(x.month / 3.0)) * 3)
    )
    return data.groupby("date_y-q").agg(
        {"transcript": " ".join, "transcript_words": "sum", "transcript_length": "sum"}
    )


def group_data_by_year(data: pd.DataFrame):
    data["date_y"] = data["date"].apply(lambda x: x.replace(day=1, month=1))
    return data.groupby("date_y").agg(
        {"transcript": " ".join, "transcript_words": "sum", "transcript_length": "sum"}
    )

# %% [markdown]
# ## Fetch Data
# Since there is no public available archive of transcripts from the governments press conferences we use subtitle data from Youtube videos.

# %% [markdown]
# ### Example-Video
# Source: https://www.youtube.com/watch?v=1-j58ggnGXM (from 15.01.2024)

# %%
date = "2024-01-15"
video_id = "1-j58ggnGXM"

print("Downloading transcript...")
transcript = get_transcript(video_id)
print(f"Found {len(transcript.split(' '))} words.")

print("Saving transcript...")
save_transcript(transcript, date, "example")
# Out:
# Downloading transcript...
# Found 8989 words.
# Saving transcript...

# %% [markdown]
# ### Playlist of Bundespresse Konferenzen
# Source: https://www.youtube.com/playlist?list=PLuQE_zb4awhV8JxSNeJzUnHskCx0eyjVj

# %%
playlist_id = "PLuQE_zb4awhV8JxSNeJzUnHskCx0eyjVj"
video_ids = get_video_ids(playlist_id, until="2020-01-01")
# save_transcripts(video_ids, "bpk")
save_data(video_ids, "bpk")

# %% [markdown]
# ## Visualize Data

# %% [markdown]
# ### Total words

# %%
import matplotlib.pyplot as plt

data = load_from_pickle(data_folder="bpk")
grouped_data = group_data_by_month(data)

# Number of total words per month

plt.plot(grouped_data["transcript_words"], label="Words per Month")

# %% [markdown]
# ### Horizontal Graphs

# %%
import matplotlib.pyplot as plt

data = load_from_pickle(data_folder="bpk")
grouped_data = group_data_by_quarter(data)

# Count specific keywords

normalize = True


def calc(x) -> float:
    f = x["transcript_words"] if normalize else 1
    return count_keywords(x["transcript"], keywords) / f


fig, axs = plt.subplots(2, 1, figsize=(10, 5), sharex=True)

keywords = [
    "migration",
    "ausländer",
    "asyl",
    "einwanderung",
    "abschiebung",
    "rückführung",
]
count_data = grouped_data.apply(calc, axis=1)
axs[0].plot(count_data, label=",".join(keywords), color="c")

keywords = [
    "energiewende",
    "erneuerbare",
    "co2",
    "klima",
    "nachhaltigkeit",
    "solar",
]
count_data = grouped_data.apply(calc, axis=1)
axs[1].plot(count_data, label=",".join(keywords), color="b")

fig.legend()
plt.show()

# %% [markdown]
# ### Stacked Area Graphs

# %%
import pandas as pd

data = load_from_pickle(data_folder="bpk")
grouped_data = group_data_by_month(data)

# keywords: list[str] = ["klima(krise|wandel)", "emission", "co2", "erneuerbare", "solar"]
keywords: list[str] = [
    # "migration",
    # "ausländer",
    "asyl",
    # "einwanderung",
    # "abschiebung",
    # "rückführung",
]
data_list = []


for k in keywords:
    # count = grouped_data.apply(lambda x: len(re.findall(k, x["transcript"], re.IGNORECASE)), axis=1).rename(k)
    count = grouped_data.apply(
        lambda x: len(re.findall(k, x["transcript"], re.IGNORECASE)),
        axis=1,
    ).rename(k)
    data_list.append(count)

data_combined = pd.concat(data_list, axis=1)
data_combined.plot.area(figsize=(10,5))
data_relative = data_combined.divide(data_combined.sum(axis=1).max())
data_relative.plot.area(figsize=(10, 5))
# Out:
# <Axes: xlabel='date_y-m'>

# %% [markdown]
# #### Signal Processing

# %%
import matplotlib.pyplot as plt
import scipy.signal as sgnl

data = load_from_pickle(data_folder="bpk")
grouped_data = group_data_by_month(data)

# Count specific keywords and convolve

normalize = True


def calc(x) -> float:
    f = x["transcript_words"] if normalize else 1
    return count_keywords(x["transcript"], keywords) / f


fig, axs = plt.subplots(1, 3, figsize=(25, 5))

keywords = ["klimakrise", "klimawandel", "emission", "co2", "erneuerbare", "solar"]
count_data = grouped_data.apply(calc, axis=1)
axs[0].plot(count_data, label=",".join(keywords))

win = sgnl.windows.hann(8)
filtered = sgnl.convolve(count_data, win, mode="same") / sum(win)
axs[1].plot(filtered)

win = sgnl.windows.hann(16)
filtered = sgnl.convolve(count_data, win, mode="same") / sum(win)
axs[2].plot(filtered)


fig.legend(loc="lower center")
plt.show()

# %% [markdown]
# ### Toplist Word

# %%
from typing import Any


data = load_from_pickle(data_folder="bpk")
grouped_data = group_data_by_month(data)

histBlacklist = ["Frage","Sie","Thema","Herr", "Frau", "Ähm", "Ähm,", "Das", "Und", "Bundesregierung", "Ich", "Ja","Ja,","Dann","Äh", "Die", "Also", "Wir", "Es", "Herrn"]
def toplist(t: str):
    array = t.split()
    list: dict[Any, Any] = {}
    for word in array:
        if word in histBlacklist or not word[:1].isupper():
            continue
        if word in list:
            list[word] = list[word] + 1
        else:
            list[word] = 1
    list = dict(filter(lambda w: w[1] > 10, list.items()))
    list = dict(sorted(list.items(), key=lambda item: item[1], reverse=True))
    print(list)
    return list

grouped_data["toplist"] = grouped_data["transcript"].apply(toplist)
# grouped_data
# Out:
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'Kanzlerin': 21, 'Bundeskanzlerin': 17, 'Fragen': 15, 'Situation': 15, 'Ihnen': 13, 'Europäischen': 11, 'Deutschland': 11, 'EU': 11}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'Woche': 20, 'Menschen': 13, 'Lage': 12, 'Tunesien': 12, 'Impfpflicht': 12, 'Afghanistan': 11}
# {}
# {'Deutschland': 24, 'Bundeskanzlerin': 17, 'Briefwahl': 13, 'Fragen': 12, 'Einsatz': 12, 'Kanzlerin': 11, 'Menschen': 11}
# {'Fragen': 18, 'Deutschland': 13, 'Afghanistan': 11}
# {}
# {}
# {'Deutschland': 25, 'Zahlen': 19, 'Woche': 16, 'Fragen': 14, 'RKI': 13}
# {}
# {}
# {'Prozent': 25, 'Energien': 20, 'Deutschland': 18, 'Paket': 12, 'Ausbau': 12, 'Maßnahmen': 12, 'Fragen': 11, 'Ende': 11}
# {}
# {'Gas': 21, 'Konferenz': 19, 'Ukraine': 13, 'Kohlekraftwerke': 13, 'Unternehmen': 13, 'Freitag': 12, 'Entscheidung': 12, 'Situation': 11}
# {'Menschen': 53, 'Euro': 38, 'Inflation': 34, 'Haushalte': 28, 'Einkommen': 22, 'Vorschlag': 19, 'Fragen': 18, 'Milliarden': 18, 'Gas': 18, 'Maßnahmen': 17, 'Deutschland': 17, 'Problem': 16, 'Dank': 16, 'Prozent': 16, 'Stresstest': 16, 'Belastung': 15, 'Beispiel': 14, 'Geld': 13, 'Diakonie': 13, 'Grundversorgung': 13, 'Punkt': 12, 'Kommunen': 12, 'Augenblick': 12, 'Szenarien': 12, 'Ukraine': 12, 'Notlage': 12, 'Studie': 11, 'Situation': 11, 'Jahr': 11, 'Ergebnisse': 11}
# {'Deutschland': 52, 'Bundeskanzler': 48, 'Fragen': 38, 'Ukraine': 34, 'Bürger': 30, 'Situation': 29, 'Zeit': 26, 'Beispiel': 25, 'Euro': 24, 'Entscheidungen': 23, 'Regierung': 23, 'Sicht': 22, 'Antwort': 20, 'Ihnen': 20, 'Jahr': 19, 'Nachfrage': 18, 'Geld': 18, 'Maßnahmen': 18, 'Lage': 17, 'Ende': 17, 'Fall': 17, 'Entscheidung': 17, 'Pressekonferenz': 16, 'Blick': 16, 'Land': 16, 'Union': 15, 'Weg': 15, 'Krieg': 15, 'Israel': 14, 'Jahren': 14, 'Stelle': 14, 'Welt': 14, 'Entlastung': 14, 'Strom': 14, 'Scholz': 13, 'Dank': 13, 'Moment': 13, 'Teil': 13, 'Zukunft': 13, 'Milliarden': 12, 'Gas': 12, 'Bundeskanzlers': 11, 'Unterstützung': 11, 'Kanzler': 11, 'Bürgerinnen': 11, 'Ländern': 11, 'Länder': 11, 'Wasser': 11, 'Unternehmen': 11, 'Verordnung': 11, 'Herausforderung': 11, 'Jahre': 11}
# {'Deutschland': 89, 'Fragen': 83, 'Menschen': 74, 'Ihnen': 48, 'Länder': 47, 'Russland': 47, 'Lage': 46, 'Beispiel': 41, 'Unternehmen': 40, 'Maßnahmen': 37, 'Situation': 35, 'Gas': 35, 'Ukraine': 34, 'Bundeskanzler': 32, 'Daten': 29, 'Schutz': 28, 'Wochen': 27, 'Seite': 27, 'Woche': 27, 'Moment': 26, 'Ländern': 26, 'Teil': 26, 'Nachfrage': 26, 'Lösung': 26, 'Regierung': 26, 'Jahr': 24, 'Blick': 24, 'Minister': 23, 'Dank': 23, 'Kabinett': 23, 'Prozent': 22, 'Büchner': 22, 'Impfung': 21, 'Zahl': 20, 'Jahren': 20, 'Botschaft': 20, 'Mittwoch': 20, 'Asyl': 20, 'Europa': 19, 'Fall': 19, 'Wohngeld': 19, 'Krieg': 19, 'Ziel': 18, 'Monaten': 18, 'Bericht': 18, 'Uhr': 18, 'Welle': 17, 'Tag': 17, 'Bevölkerung': 17, 'Zeit': 17, 'Versorgungssicherheit': 17, 'York': 17, 'Kollegen': 16, 'Herbst': 16, 'Winter': 16, 'Infrastruktur': 16, 'Augenblick': 16, 'Bund': 16, 'New': 16, 'Impfstoffe': 15, 'Impfstoff': 15, 'Verfügung': 15, 'Weg': 15, 'Zahlen': 15, 'Dunkelziffer': 15, 'September': 15, 'Informationen': 15, 'Pipeline': 15, 'Gesamtlösung': 15, 'Finanzministerium': 15, 'Amt': 15, 'Iran': 15, 'Zeitpunkt': 14, 'Gesetz': 14, 'Risiko': 14, 'Millionen': 14, 'Land': 14, 'Hintergrund': 14, 'Ende': 14, 'Ministerien': 14, 'Bürger': 14, 'Juniper': 14, 'Kenntnis': 14, 'BMI': 14, 'Verfolgung': 14, 'Berlin': 14, 'Möglichkeit': 13, 'Dinge': 13, 'Sicht': 13, 'Punkt': 13, 'Schritt': 13, 'Entwicklung': 13, 'Möglichkeiten': 13, 'Aufgabe': 13, 'Antwort': 13, 'Asylrecht': 13, 'Russen': 13, 'Lauterbach': 12, 'Betten': 12, 'Grundlage': 12, 'Stelle': 12, 'Euro': 12, 'Verordnung': 12, 'Themen': 12, 'Kanzler': 12, 'Abstimmung': 12, 'Milliarden': 12, 'Anfang': 12, 'Asylverfahren': 12, 'Leute': 11, 'Kraft': 11, 'Corona': 11, 'Zukunft': 11, 'Krankenhäuser': 11, 'Infektion': 11, 'Interesse': 11, 'Verfahren': 11, 'Bürgerinnen': 11, 'Heizkostenzuschuss': 11, 'Hochdruck': 11, 'Gespräche': 11, 'Ministerium': 11, 'Erkenntnisse': 11, 'Komplex': 11, 'Haltung': 11, 'Visa': 11}
# {'Fragen': 167, 'Deutschland': 138, 'Menschen': 80, 'Bundeskanzler': 78, 'Ihnen': 77, 'Woche': 68, 'Fall': 65, 'Stelle': 62, 'Kommission': 54, 'Ende': 51, 'Minister': 48, 'Gas': 48, 'Nachfrage': 47, 'Infrastruktur': 47, 'Jahr': 47, 'Zeit': 46, 'Moment': 45, 'Ukraine': 44, 'Iran': 42, 'Ziel': 42, 'Seite': 42, 'Dank': 42, 'Länder': 40, 'Gespräche': 39, 'Bund': 39, 'Verfahren': 38, 'Sicht': 37, 'Kollegen': 36, 'Hebestreit': 36, 'Ausbau': 36, 'Maßnahmen': 35, 'Energie': 35, 'Schritt': 35, 'Freitag': 35, 'Lage': 34, 'BMI': 34, 'Beispiel': 34, 'Vorschlag': 33, 'Kanzler': 33, 'Zeitpunkt': 32, 'China': 32, 'Grundlage': 32, 'Zahl': 31, 'Ländern': 31, 'Prüfung': 31, 'Rahmen': 31, 'Amt': 30, 'Entscheidung': 30, 'Blick': 30, 'Lösung': 30, 'Unternehmen': 30, 'Ort': 30, 'Gesprächen': 29, 'Teil': 29, 'Cannabis': 29, 'Themen': 28, 'Hoffmann': 28, 'Kolleginnen': 27, 'Zahlen': 27, 'Stand': 27, 'Möglichkeit': 27, 'Informationen': 27, 'Umsetzung': 27, 'Uhr': 27, 'Dinge': 27, 'Euro': 27, 'Regierung': 26, 'Kabinett': 26, 'Augenblick': 25, 'Außenministerin': 25, 'Reise': 25, 'Milliarden': 25, 'Eckpunkte': 25, 'Masterplan': 25, 'Jahren': 24, 'Jung': 24, 'Weg': 24, 'Kollege': 24, 'Gespräch': 23, 'Bundeskanzlers': 23, 'Europa': 23, 'Kenntnis': 23, 'Position': 23, 'Antwort': 22, 'Zusammenhang': 22, 'Ergebnis': 22, 'Ministerin': 22, 'Form': 22, 'Vorschläge': 22, 'Pressekonferenz': 22, 'Einigung': 22, 'Probleme': 22, 'Bereich': 21, 'Gesetzentwurf': 21, 'Markt': 21, 'Tagen': 21, 'Ebene': 21, 'Abstimmung': 21, 'Tag': 21, 'Details': 21, 'Russland': 21, 'Wochen': 21, 'Projekt': 21, 'Ermittlungen': 21, 'Elektromobilität': 21, 'Netz': 21, 'Afghanistan': 21, 'Möglichkeiten': 20, 'Jessen': 20, 'Interesse': 20, 'Januar': 20, 'Verhandlungen': 20, 'Kanzlers': 20, 'Staaten': 20, 'Situation': 20, 'Geld': 19, 'März': 19, 'Anfang': 19, 'Ministerium': 19, 'Bericht': 19, 'Dezember': 19, 'Ziele': 19, 'Einsatz': 19, 'EU': 18, 'Zeitplan': 18, 'Plan': 18, 'Wirtschaftsministerium': 18, 'Oktober': 18, 'Ergebnisse': 18, 'Einschätzung': 18, 'Zusammenarbeit': 18, 'Europäischen': 18, 'Arbeit': 18, 'Anbau': 18, 'Bundespressekonferenz': 17, 'Gesetz': 17, 'Bundestag': 17, 'Wochenende': 17, 'Jahres': 17, 'Liste': 17, 'Leute': 17, 'Sinne': 17, 'Verfügung': 17, 'Besitz': 17, 'Ticket': 17, 'Atomkraftwerke': 17, 'Ministerien': 16, 'Botschaft': 16, 'Treffen': 16, 'Problem': 16, 'Bewertung': 16, 'Diskussion': 16, 'Stellen': 16, 'Fracking': 16, 'Art': 16, 'Haltung': 16, 'Termin': 16, 'Akten': 16, 'Koalitionsvertrag': 16, 'Austausch': 16, 'G7': 16, 'Jugendschutz': 16, 'Nutzung': 16, 'Komplex': 16, 'Ladeinfrastruktur': 16, 'Partnern': 15, 'Welt': 15, 'Land': 15, 'Erkenntnisse': 15, 'Verständnis': 15, 'Rinke': 15, 'Punkt': 15, 'Vergangenheit': 15, 'Monate': 15, 'Rolle': 15, 'Mittwoch': 15, 'Aufgabe': 15, 'Termine': 15, 'Wirtschaft': 15, 'Berlin': 15, 'Konsum': 15, 'Kollegin': 15, 'Brennstäbe': 15, 'Öl': 15, 'Baron': 14, 'Kritik': 14, 'Millionen': 14, 'Weise': 14, 'Kanzleramt': 14, 'November': 14, 'Monaten': 14, 'Zukunft': 14, 'Angebot': 14, 'System': 14, 'Kommunen': 14, 'Auswärtige': 13, 'Außenminister': 13, 'Sache': 13, 'Personen': 13, 'Raum': 13, 'Seiten': 13, 'Berichterstattung': 13, 'Stream': 13, 'Finanzministerium': 13, 'BMG': 13, 'Jahre': 13, 'Mitglied': 13, 'Prozent': 13, 'Gramm': 13, 'Hintergrund': 12, 'Punkte': 12, 'BMF': 12, 'Klimaschutz': 12, 'Kriterien': 12, 'Richtung': 12, 'Rede': 12, 'Entwicklung': 12, 'Unterstützung': 12, 'Lauterbach': 12, 'Cannabiskonsum': 12, 'Verträge': 12, 'Bundeswehr': 12, 'Betreiber': 12, 'Laden': 12, 'BSI': 12, 'Ihre': 11, 'Fälle': 11, 'Innenministerium': 11, 'Union': 11, 'Kontext': 11, 'Bürgerinnen': 11, 'September': 11, 'Sicherheit': 11, 'Nord': 11, 'Grund': 11, 'Unterschied': 11, 'Schiene': 11, 'Ressortabstimmung': 11, 'Bundeskanzleramt': 11, 'Montag': 11, 'Dienstag': 11, 'Produktion': 11, 'Strom': 11, 'Obergrenze': 11, 'Niederlanden': 11, 'Pflanzen': 11, 'Zusatz': 11, 'Verkauf': 11, 'Person': 11, 'Beteiligung': 11, 'Frankreich': 11, 'Bundespolizei': 11, ...
# {'Fragen': 195, 'Deutschland': 167, 'Jahr': 125, 'Regierung': 100, 'Ihnen': 97, 'Ukraine': 93, 'Beispiel': 88, 'Milliarden': 87, 'Bundeskanzler': 87, 'Menschen': 83, 'Euro': 73, 'Teil': 73, 'Bereich': 66, 'Seite': 66, 'Dank': 65, 'Unternehmen': 64, 'Nachfrage': 64, 'Gas': 62, 'Stelle': 62, 'Millionen': 60, 'Fall': 57, 'Moment': 56, 'Jahren': 54, 'Ländern': 53, 'Ende': 50, 'Rahmen': 47, 'China': 47, 'Prozent': 46, 'Zeit': 45, 'Woche': 45, 'Gespräche': 45, 'Verfahren': 44, 'Ziel': 44, 'Maßnahmen': 44, 'Dinge': 44, 'Iran': 42, 'Ministerin': 42, 'Länder': 42, 'Kollegen': 41, 'Themen': 41, 'Situation': 41, 'EU': 40, 'Polizei': 40, 'Kabinett': 39, 'Zahlen': 39, 'Entscheidung': 39, 'Haushalt': 39, 'Möglichkeit': 38, 'Staaten': 38, 'Inflation': 37, 'Reise': 37, 'Gesundheit': 36, 'Blick': 36, 'Ministerien': 35, 'Jahre': 35, 'Außenministerin': 34, 'Gespräch': 34, 'Sicht': 34, 'Geld': 34, 'Komplex': 34, 'Daten': 34, 'Schuldenbremse': 34, 'Kollege': 33, 'Lage': 33, 'Zusammenhang': 33, 'Ort': 33, 'Sicherheit': 32, 'Jessen': 32, 'Dingen': 32, 'Tag': 31, 'Entwicklung': 31, 'Arbeit': 31, 'Land': 31, 'Weg': 31, 'Bundeswehr': 31, 'Punkt': 30, 'Berichte': 30, 'Industrie': 30, 'Klimawandel': 30, 'Dezember': 29, 'Weise': 29, 'Zahl': 29, 'November': 28, 'Montag': 28, 'Russland': 28, 'Bericht': 27, 'Zeitpunkt': 27, 'Amt': 27, 'Verantwortung': 27, 'Türkei': 27, 'Punkte': 26, 'Minister': 26, 'Politik': 26, 'Schritt': 26, 'Verfügung': 26, 'Koalitionsvertrag': 25, 'Anfang': 25, 'Kenntnis': 25, 'Krise': 25, 'Stand': 25, 'Verhandlungen': 25, 'Mittwoch': 24, 'Studie': 24, 'Bevölkerung': 24, 'USA': 24, 'Europa': 24, 'Möglichkeiten': 24, 'Rinke': 24, 'Recht': 24, 'Wochen': 24, 'Sondervermögen': 24, 'Vorhaben': 23, 'Energien': 23, 'Stellen': 23, 'Bund': 23, 'Strategie': 23, 'Klimaschutz': 23, 'Art': 23, 'Details': 23, 'Kanzler': 23, 'Mittel': 23, 'Frauen': 23, 'Hebestreit': 22, 'Infrastruktur': 22, 'Pressekonferenz': 22, 'Diskussion': 22, 'Polen': 22, 'Straftaten': 22, 'Antwort': 21, 'Gesprächen': 21, 'Rolle': 21, 'Katar': 21, 'Berlin': 21, 'Richtung': 21, 'Twitter': 21, 'Bürger': 21, 'Monaten': 21, 'Abstimmung': 21, 'Opfer': 21, 'Freitag': 21, 'Sache': 21, 'Wirtschaft': 20, 'Energie': 20, 'Problem': 20, 'Grunde': 20, 'Schutz': 20, 'Menschenrechte': 20, 'Liste': 20, 'Tagen': 20, 'Entlastung': 20, 'Gesetz': 20, 'Uhr': 20, 'Büchner': 20, 'Kriminalität': 20, 'Aufgabe': 20, 'Bundespressekonferenz': 19, 'Zusammenarbeit': 19, 'Jung': 19, 'Folgen': 19, 'Ebene': 19, 'Auswirkungen': 19, 'Präsidenten': 19, 'Position': 19, 'Hintergrund': 19, 'Unterstützung': 19, 'Form': 19, 'Entscheidungen': 18, 'Umsetzung': 18, 'Bekämpfung': 18, 'Union': 18, 'Gewalt': 18, 'Parlament': 18, 'Ministerium': 18, 'Kinder': 18, 'Ausbau': 17, 'Leben': 17, 'Leute': 17, 'Austausch': 17, 'BMI': 17, 'Angriffe': 17, 'Grenze': 17, 'Dankeschön': 17, 'Behörden': 17, 'Herren': 17, 'Jahres': 16, 'Angebot': 16, 'Entschuldigung': 16, 'Klima': 16, 'Tatsache': 16, 'Sinne': 16, 'Sprecher': 16, 'Bundestag': 16, 'Wort': 16, 'Welt': 16, 'Investitionen': 16, 'Haus': 16, 'Klimawandels': 16, 'Zukunft': 16, 'Schweiz': 16, 'Abhängigkeit': 16, 'Zwangsarbeit': 16, 'Kolleginnen': 15, 'Gesetzentwurf': 15, 'Deutschen': 15, 'Prozess': 15, 'Vorgehen': 15, 'Präsident': 15, 'Februar': 15, 'Gründe': 15, 'Haltung': 15, 'Personen': 15, 'Kosovo': 15, 'Lösung': 15, 'Hilfe': 15, 'Bundeskanzlers': 15, 'März': 15, 'Fonds': 15, 'Klimakrise': 15, 'Kopf': 15, 'Anliegen': 15, 'Koalition': 15, 'Ergebnis': 14, 'Reform': 14, 'Gesellschaft': 14, 'Demokratie': 14, 'Augenblick': 14, 'Finanzierung': 14, 'System': 14, 'Mal': 14, 'Auswärtigen': 14, 'Diskussionen': 14, 'Einschätzung': 14, 'Kontakt': 14, 'Mali': 14, 'Mission': 14, 'Bezug': 14, 'BMZ': 14, 'Verständnis': 14, 'Erkenntnisse': 14, 'Haushaltsausschuss': 14, 'Informationen': 14, 'Wochenende': 14, 'Milliarde': 14, 'Studierende': 14, 'BKA': 14, 'Bereinigungssitzung': 14, 'Ausgaben': 14, 'Damen': 14, 'Energiekrise': 14, 'Einigung': 13, 'Grundlage': 13, 'Partnern': 13, 'Bedeutung': 13, 'Kris ...
# {'Deutschland': 147, 'Fragen': 134, 'Fall': 88, 'Jahr': 85, 'Menschen': 77, 'Ukraine': 68, 'Bundeskanzler': 67, 'Demokratie': 67, 'Ihnen': 64, 'Beispiel': 64, 'System': 64, 'Länder': 62, 'Seite': 58, 'Jahren': 57, 'Maßnahmen': 57, 'Teil': 52, 'Woche': 50, 'Dank': 50, 'Gesetz': 49, 'Krankenhäuser': 48, 'Arbeit': 46, 'Nachfrage': 45, 'Ländern': 45, 'Kollegen': 43, 'Moment': 43, 'Minister': 43, 'Jahre': 42, 'Geld': 41, 'Krankenhaus': 41, 'Reform': 40, 'Regierung': 39, 'Sicht': 38, 'Ziel': 38, 'Unternehmen': 38, 'Ende': 36, 'Versorgung': 36, 'Bericht': 36, 'Punkt': 36, 'Gespräche': 35, 'Ministerin': 35, 'Bereich': 35, 'Twitter': 35, 'Wochen': 34, 'Iran': 34, 'Kliniken': 34, 'Kanzler': 32, 'Themen': 32, 'Situation': 32, 'Rahmen': 32, 'Zeit': 31, 'Förderung': 31, 'Prozent': 31, 'Kommission': 31, 'Rolle': 30, 'Stand': 30, 'Hebestreit': 29, 'Infrastruktur': 29, 'Möglichkeit': 28, 'Russland': 28, 'Zukunft': 27, 'Amt': 26, 'Informationen': 26, 'Ort': 26, 'EU': 26, 'Schutz': 26, 'Puma': 25, 'Augenblick': 25, 'Außenministerin': 25, 'Bund': 25, 'Land': 25, 'Level': 25, 'Patienten': 25, 'Tag': 23, 'Hoffmann': 23, 'Euro': 23, 'Fälle': 23, 'Qualität': 23, 'Entscheidung': 22, 'Lage': 22, 'Leistung': 22, 'Problem': 22, 'Grundlage': 22, 'Treffen': 22, 'Millionen': 21, 'Stelle': 21, 'Mal': 21, 'Personal': 21, 'Mittwoch': 20, 'Freitag': 20, 'Weg': 20, 'Ministerium': 19, 'Möglichkeiten': 19, 'Monaten': 19, 'Plattform': 19, 'Rinke': 19, 'Milliarden': 19, 'Zivilgesellschaft': 18, 'Details': 18, 'Anfang': 18, 'Verständnis': 18, 'Schritt': 18, 'Bevölkerung': 18, 'Tat': 18, 'Zahlen': 18, 'Dinge': 18, 'Hilfe': 18, 'Einsatz': 18, 'Verfügung': 18, 'Kinder': 17, 'Ebene': 17, 'Kollege': 17, 'Gesprächen': 17, 'Entwicklung': 17, 'Lauterbach': 17, 'Krankenhäusern': 17, 'Pandemie': 17, 'Frauen': 17, 'Umsetzung': 17, 'Unterstützung': 17, 'Kosten': 17, 'Kenntnis': 17, 'Diskussion': 17, 'Regierungskommission': 17, 'Pressekonferenz': 16, 'Uhr': 16, 'Zeitpunkt': 16, 'Blick': 16, 'Druck': 16, 'Staat': 16, 'Zusammenhang': 16, 'Position': 16, 'Antwort': 16, 'Aufgabe': 16, 'Bundeswehr': 16, 'Projekte': 16, 'Reichsbürger': 16, 'Medizin': 16, 'Ermittlungen': 15, 'Bürger': 15, 'Haus': 15, 'Meinung': 15, 'Rente': 15, 'Gesellschaft': 15, 'Prozess': 15, 'USA': 15, 'Komplex': 15, 'Probleme': 15, 'Waffen': 15, 'Gewinne': 15, 'Kolleginnen': 14, 'Ministerien': 14, 'Zusammenarbeit': 14, 'Januar': 14, 'Welt': 14, 'China': 14, 'Interview': 14, 'Finanzierung': 14, 'Bereichen': 14, 'Menschenrechte': 14, 'Austausch': 14, 'Außenminister': 14, 'Europa': 14, 'Parlament': 14, 'Präsidenten': 14, 'Projekt': 14, 'Eckpunkte': 14, 'Jessen': 14, 'BMZ': 13, 'Sicherheitsbehörden': 13, 'Auswärtige': 13, 'Voraussetzungen': 13, 'Verhandlungen': 13, 'Wort': 13, 'Afghanistan': 13, 'Besuch': 13, 'Staaten': 13, 'Verantwortung': 13, 'Sinne': 13, 'Verfahren': 13, 'Sicherheit': 13, 'Ergebnis': 13, 'Montag': 13, 'Förderrichtlinien': 13, 'KSK': 13, 'Kinderkliniken': 13, 'Konzept': 13, 'Reise': 12, 'Programm': 12, 'Gespräch': 12, 'Zahl': 12, 'Bundesamt': 12, 'Einschätzung': 12, 'Art': 12, 'Deutschen': 12, 'Taliban': 12, 'Engagement': 12, 'Jung': 12, 'Nationen': 12, 'Menge': 12, 'Vorschlag': 12, 'Krieg': 12, 'Dingen': 12, 'Gesetzentwurf': 12, 'Liste': 12, 'Berlin': 12, 'Angebot': 12, 'Legislaturperiode': 12, 'Generation': 12, 'Aspekte': 12, 'Tafeln': 12, 'Leistungsgruppen': 12, 'Ankündigung': 11, 'Politik': 11, 'Richtung': 11, 'BMI': 11, 'Industrie': 11, 'Innenminister': 11, 'Tage': 11, 'Grund': 11, 'Öl': 11, 'Schwedt': 11, 'Lufthansa': 11, 'F35': 11, 'Gewalt': 11, 'Bildung': 11, 'Bundestag': 11, 'Vorschläge': 11, 'Kriterien': 11, 'Vordergrund': 11, 'Vorhaltung': 11}
# {'Deutschland': 163, 'Ukraine': 154, 'Fragen': 145, 'Bundeskanzler': 90, 'Länder': 84, 'Jahr': 79, 'Entscheidung': 74, 'Rassismus': 72, 'Ihnen': 70, 'Regierung': 69, 'Nachfrage': 69, 'Minister': 64, 'Fall': 64, 'Menschen': 64, 'Ministerin': 63, 'Hoffmann': 60, 'Dank': 59, 'Woche': 52, 'Zahlen': 51, 'Amt': 50, 'Stelle': 50, 'Kollegen': 47, 'Zeit': 46, 'Gespräche': 46, 'Leopard': 44, 'Beispiel': 44, 'Diskussion': 44, 'Polizei': 42, 'Freitag': 41, 'Seite': 39, 'Russland': 39, 'Klimaschutz': 39, 'Schritt': 38, 'Ende': 37, 'Öl': 37, 'Bericht': 37, 'Panzer': 36, 'Maßnahmen': 36, 'Land': 36, 'Moment': 34, 'Unterstützung': 34, 'Partnern': 34, 'Teil': 34, 'Themen': 33, 'Sicht': 33, 'Kanzler': 32, 'Ländern': 32, 'Lieferung': 32, 'Stand': 31, 'Bundeswehr': 31, 'Uhr': 31, 'Ministerium': 31, 'Wochen': 31, 'Informationen': 31, 'Zusammenhang': 30, 'Debatte': 30, 'Kollege': 30, 'NATO': 29, 'Abstimmung': 29, 'Situation': 29, 'Blick': 29, 'Unternehmen': 29, 'Gespräch': 28, 'Lage': 28, 'Monaten': 28, 'USA': 27, 'Wirtschaft': 27, 'Berlin': 26, 'Kenntnis': 26, 'Position': 25, 'Krieg': 25, 'Kommunen': 25, 'Liste': 25, 'Montag': 25, 'Prozent': 24, 'Jahren': 24, 'Januar': 24, 'Entwicklung': 24, 'Punkt': 24, 'Ziel': 23, 'Partner': 23, 'Außenministerin': 23, 'Ort': 23, 'Gesprächen': 23, 'Verteidigungsministerium': 23, 'Kolleginnen': 22, 'Haltung': 22, 'Europa': 22, 'Auswärtigen': 22, 'Antwort': 22, 'Iran': 22, 'Wort': 22, 'Bereich': 21, 'Staaten': 21, 'Weg': 21, 'Botschaft': 21, 'Präsident': 21, 'Verkehr': 21, 'Entscheidungen': 21, 'Polen': 21, 'Hebestreit': 21, 'Treffen': 20, 'EU': 20, 'Termin': 19, 'Zeitpunkt': 19, 'Hintergrund': 19, 'Kampfpanzer': 19, 'Auswärtige': 19, 'Bezug': 19, 'Dingen': 19, 'Art': 19, 'BMI': 19, 'Rolle': 19, 'Rahmen': 18, 'Äußerungen': 18, 'Zusammenarbeit': 18, 'Äußerung': 18, 'Koalitionsvertrag': 18, 'Möglichkeiten': 18, 'Jahres': 18, 'Dezember': 18, 'Tage': 18, 'Plan': 18, 'Tag': 17, 'Mittwoch': 17, 'Sachen': 17, 'Erkenntnisse': 17, 'Form': 17, 'Austausch': 17, 'Pipeline': 17, 'Indien': 17, 'Märkte': 17, 'Arbeit': 17, 'Anfrage': 17, 'Silvesternacht': 17, 'Puma': 17, 'Bundeskanzlers': 16, 'Richtung': 16, 'Kanzleramt': 16, 'Bürger': 16, 'Prozess': 16, 'Zukunft': 16, 'Recht': 16, 'Grund': 16, 'Pressekonferenz': 16, 'Aufgabe': 16, 'Präsidenten': 16, 'Marder': 16, 'Journalisten': 16, 'Vorschlag': 16, 'Möglichkeit': 15, 'Wochenende': 15, 'Kriegspartei': 15, 'Welt': 15, 'Verfahren': 15, 'Bundesländern': 15, 'Kontakt': 15, 'Behörden': 15, 'Anfang': 15, 'Bundespressekonferenz': 15, 'Reise': 15, 'Ergebnis': 15, 'Industrie': 15, 'Raum': 15, 'Rede': 15, 'Leute': 15, 'Vertreter': 15, 'Monate': 15, 'Transformation': 15, 'Büchner': 15, 'Panzern': 14, 'Meinung': 14, 'Verbündeten': 14, 'Aussagen': 14, 'Kanzlers': 14, 'Prinzipien': 14, 'Berichterstattung': 14, 'Erklärung': 14, 'Stichwort': 14, 'Sinne': 14, 'Kabinett': 14, 'Einsatz': 14, 'Sache': 14, 'Gas': 14, 'Gewalt': 14, 'Kritik': 14, 'Mitte': 14, 'Lambrecht': 14, 'Türkei': 14, 'Scholz': 14, 'Details': 14, 'Sofortprogramm': 14, 'Presse': 13, 'Linie': 13, 'Botschafter': 13, 'Fokus': 13, 'Euro': 13, 'Komplex': 13, 'Aufgaben': 13, 'Bewertung': 13, 'Israel': 13, 'Grundlage': 13, 'Vergangenheit': 13, 'Sicherheit': 13, 'Bundesländer': 13, 'Schweden': 13, 'Ausbau': 13, 'Wagner': 13, 'Regeln': 13, 'Investitionen': 13, 'Leben': 13, 'Vereinigten': 13, 'Schützenpanzer': 13, 'Ministerien': 12, 'Februar': 12, 'Kampfjets': 12, 'Ausbildung': 12, 'Zahl': 12, 'Bundes': 12, 'Prinzip': 12, 'Frist': 12, 'Eskalation': 12, 'Antrag': 12, 'Verkehrsministerium': 12, 'Reihe': 12, 'Mal': 12, 'China': 12, 'Tagen': 12, 'Jahre': 12, 'Dinge': 12, 'Bedingungen': 12, 'Ermittlungen': 12, 'Bild': 12, 'Verfügung': 12, 'Entschuldigung': 12, 'Problem': 12, 'Rammstein': 12, 'Lagebild': 12, 'Öffentlichkeit': 12, 'Tempolimit': 12, 'Finanzministerium': 11, 'Innenministerium': 11, 'Seiten': 11, 'Ihre': 11, 'Verständnis': 11, 'Tempo': 11, 'Schutz': 11, 'Bund': 11, 'Aussage': 11, 'Energien': 11, 'Europäischen': 11, 'Waffen': 11, 'Land ...
# {'Fragen': 155, 'Deutschland': 154, 'Ukraine': 152, 'Bundeskanzler': 128, 'Gespräche': 90, 'Menschen': 85, 'Ihnen': 82, 'Jahr': 78, 'Hilfe': 68, 'Länder': 60, 'Türkei': 60, 'Nachfrage': 59, 'Regierung': 57, 'Ort': 55, 'Seite': 54, 'Stelle': 54, 'Euro': 53, 'Fall': 52, 'Themen': 49, 'Verfahren': 49, 'Dank': 48, 'Position': 48, 'Beispiel': 48, 'Reise': 46, 'Syrien': 46, 'Lage': 45, 'Woche': 45, 'Russland': 43, 'Teil': 42, 'Ziel': 41, 'Minister': 41, 'Gespräch': 40, 'Leopard': 39, 'Außenministerin': 39, 'Entscheidung': 38, 'Ende': 38, 'EU': 37, 'Moment': 37, 'Ländern': 37, 'Zeit': 36, 'Partnern': 35, 'Bund': 35, 'Kollegen': 34, 'Hebestreit': 34, 'Abstimmung': 34, 'Bundeswehr': 34, 'Millionen': 34, 'Milliarden': 33, 'Situation': 33, 'Ministerin': 33, 'Gesprächen': 33, 'Rahmen': 33, 'Staaten': 32, 'Pressekonferenz': 32, 'Uhr': 32, 'Tag': 32, 'Zahl': 31, 'Erkenntnisse': 31, 'Zeitpunkt': 30, 'Jessen': 30, 'Büchner': 28, 'Zahlen': 28, 'Kommunen': 28, 'Amt': 27, 'Raum': 27, 'Lieferung': 27, 'Panzer': 26, 'Kollege': 26, 'Kanzler': 26, 'Weg': 26, 'Nationen': 26, 'Verfügung': 26, 'Mittwoch': 26, 'Winter': 26, 'Informationen': 26, 'Sicht': 25, 'Jahren': 25, 'Montag': 24, 'Bundeskanzlers': 24, 'Jung': 24, 'Kenntnis': 24, 'Bericht': 24, 'Augenblick': 24, 'März': 24, 'Austausch': 24, 'Erdbeben': 24, 'Frauen': 24, 'Weise': 23, 'Sicherheit': 23, 'Koalitionsvertrag': 23, 'Wochen': 22, 'Unterstützung': 22, 'Vereinten': 22, 'Präsident': 21, 'Unternehmen': 21, 'Kabinett': 21, 'Krieg': 21, 'Februar': 21, 'Antwort': 21, 'Entwurf': 21, 'Äußerung': 20, 'USA': 20, 'Besuch': 20, 'Land': 20, 'Jahres': 20, 'Indien': 20, 'Möglichkeit': 20, 'Ermittlungen': 20, 'Anfang': 20, 'Infrastruktur': 20, 'Kampfjets': 20, 'Ministerien': 19, 'Verhandlungen': 19, 'Rolle': 19, 'Maßnahmen': 19, 'Entwicklung': 19, 'Stand': 19, 'Punkt': 19, 'Blick': 19, 'Region': 19, 'Aussage': 18, 'Linie': 18, 'Vorhaben': 18, 'Aufgabe': 18, 'Ankündigung': 18, 'Termin': 18, 'Geld': 18, 'Hilfen': 18, 'Präsidenten': 17, 'Vergangenheit': 17, 'Scholz': 17, 'Haus': 17, 'Kommission': 17, 'Arbeit': 17, 'Ministerium': 17, 'China': 17, 'Liste': 17, 'Mittel': 17, 'BMI': 17, 'Tagen': 17, 'Organisationen': 17, 'Diskussion': 17, 'Rinke': 17, 'Auswärtige': 16, 'Forderung': 16, 'Seiten': 16, 'Medien': 16, 'Einsatz': 16, 'Beitrag': 16, 'Voraussetzungen': 16, 'Bundestag': 16, 'Grundlage': 16, 'Iran': 16, 'Angriffskrieg': 16, 'Freitag': 16, 'Zusammenarbeit': 16, 'Konflikt': 16, 'Komplex': 16, 'Prozess': 16, 'Schweden': 16, 'THW': 16, 'Debatte': 16, 'Finnland': 16, 'Sasse': 16, 'Kolleginnen': 15, 'Details': 15, 'Partner': 15, 'Punkte': 15, 'Grenze': 15, 'Berichte': 15, 'Presse': 15, 'Innenministerin': 15, 'Europäischen': 15, 'Wohnungen': 15, 'Industrie': 15, 'EU-Kommission': 15, 'Einschätzung': 14, 'Prozent': 14, 'Finanzministerium': 14, 'Ihrer': 14, 'Europa': 14, 'Anschluss': 14, 'Rede': 14, 'Organisation': 14, 'Wege': 14, 'Krieges': 14, 'Reihe': 14, 'Sanktionen': 14, 'Subventionen': 14, 'Wort': 14, 'Migration': 14, 'Sprecher': 13, 'Deutschen': 13, 'Bereich': 13, 'Äußerungen': 13, 'Ergebnisse': 13, 'Art': 13, 'Zukunft': 13, 'Treffen': 13, 'Mission': 13, 'Januar': 13, 'Kontakt': 13, 'Zitat': 13, 'Termine': 13, 'Dingen': 13, 'Kinder': 13, 'Ausbau': 13, 'Urteil': 13, 'Kollegin': 13, 'Form': 13, 'Generalbundesanwalt': 13, 'Antrag': 13, 'Visa': 13, 'NATO': 13, 'Monate': 13, 'Regierungssprecher': 12, 'Bedingungen': 12, 'Monaten': 12, 'Wahlen': 12, 'Mali': 12, 'Aktion': 12, 'Prüfung': 12, 'Hinweise': 12, 'Leute': 12, 'Haltung': 12, 'Berlin': 12, 'Donnerstag': 12, 'Kritik': 12, 'Bezug': 12, 'Gewalt': 12, 'Problem': 12, 'Wirtschaftsministerium': 12, 'Schritt': 12, 'Taliban': 12, 'Bundespressekonferenz': 11, 'Angehörigen': 11, 'Wochenende': 11, 'Forderungen': 11, 'Integrität': 11, 'Dinge': 11, 'Sache': 11, 'Eckstein': 11, 'Regel': 11, 'Bedarf': 11, 'Wirtschaft': 11, 'Vorschläge': 11, 'Stellen': 11, 'Öl': 11, 'Kanzlers': 11, 'Ebene': 11, 'Verständnis': 11, 'Haushalt': 11, 'Recht': 11, 'November': 11, 'Anträge': 11, 'Bot ...
# {'Fragen': 212, 'Deutschland': 147, 'Bundeskanzler': 90, 'Minister': 77, 'Ihnen': 74, 'Regierung': 72, 'Ukraine': 71, 'Fall': 64, 'Menschen': 63, 'Stelle': 61, 'Nachfrage': 58, 'Jahr': 57, 'Ziel': 57, 'Länder': 55, 'Themen': 53, 'Zeit': 53, 'Gespräche': 50, 'Ländern': 50, 'Kanzler': 48, 'Kommunen': 48, 'Reise': 47, 'Beispiel': 47, 'Verfahren': 44, 'Woche': 43, 'Teil': 42, 'Uhr': 41, 'Dank': 39, 'Hebestreit': 38, 'Weg': 38, 'Bereich': 38, 'Unternehmen': 38, 'Besuch': 37, 'Seite': 37, 'Ende': 37, 'Kollegen': 36, 'Maßnahmen': 36, 'Fachkräfte': 35, 'Freitag': 34, 'Gespräch': 33, 'Komplex': 33, 'Blick': 33, 'Haushalt': 33, 'Ministerin': 33, 'Stand': 32, 'Zahlen': 32, 'Land': 30, 'Position': 30, 'Pressekonferenz': 29, 'Ziele': 28, 'Rahmen': 28, 'China': 28, 'Visa': 28, 'März': 27, 'Kollege': 27, 'Millionen': 27, 'Wasser': 27, 'Bund': 26, 'Wochen': 25, 'Gesetz': 25, 'Lage': 25, 'Jahren': 25, 'Europäischen': 24, 'Zahl': 24, 'Haltung': 24, 'Hoffmann': 24, 'Arbeit': 23, 'Termin': 23, 'Kabinett': 23, 'Russland': 23, 'Gesprächen': 22, 'Erkenntnisse': 22, 'Jahre': 22, 'Vorschlag': 22, 'Rolle': 22, 'Augenblick': 22, 'Interview': 22, 'Klimaziele': 22, 'Strategie': 22, 'Situation': 21, 'Antwort': 21, 'Regelung': 21, 'Lösung': 21, 'Förderung': 21, 'Bundeskanzlers': 20, 'Zeitpunkt': 20, 'Ort': 20, 'EU': 20, 'Verkehr': 20, 'Koalition': 20, 'Wirtschaft': 20, 'Hintergrund': 19, 'Kommission': 19, 'Rinke': 19, 'Verständnis': 19, 'Moment': 19, 'Dingen': 19, 'Iran': 19, 'Weise': 19, 'Klima': 19, 'Israel': 19, 'Komponenten': 19, 'Unterstützung': 18, 'Ministerpräsidenten': 18, 'Ministerium': 18, 'Koalitionsvertrag': 18, 'Diskussion': 18, 'Abstimmung': 18, 'Sicht': 18, 'Möglichkeit': 18, 'Problem': 18, 'Tag': 18, 'Jung': 18, 'Meseberg': 18, 'Energien': 18, 'Europa': 17, 'Punkt': 17, 'Entwurf': 17, 'Dinge': 17, 'Kolleginnen': 17, 'Ergebnisse': 17, 'Verfügung': 17, 'Amt': 17, 'Tage': 17, 'Informationen': 17, 'Ankündigung': 17, 'Sprecher': 16, 'Moldau': 16, 'Kanzleramt': 16, 'Treffen': 16, 'Ergebnis': 16, 'Anfang': 16, 'Politik': 16, 'Liste': 16, 'Kenntnis': 16, 'Ihre': 16, 'Ausland': 16, 'Prozess': 16, 'Ausbildung': 16, 'Industrie': 16, 'Finanzministerium': 16, 'Berlin': 15, 'Entscheidung': 15, 'Termine': 15, 'Behörden': 15, 'Berichterstattung': 15, 'Vorhaben': 15, 'Ausbau': 15, 'Austausch': 15, 'Schritt': 15, 'Parteien': 15, 'Haus': 15, 'Euro': 15, 'Zukunft': 15, 'Ebene': 15, 'BMI': 15, 'Zeitplan': 15, 'Einwanderung': 15, 'Entwicklung': 15, 'Kollegin': 15, 'Tat': 15, 'Einsatz': 15, 'Athleten': 15, 'Berichte': 14, 'Sache': 14, 'Jessen': 14, 'Form': 14, 'Bundeswehr': 14, 'Kontakt': 14, 'Staaten': 14, 'Kanada': 14, 'Präsident': 14, 'Außenministerin': 14, 'Details': 14, 'Ermittlungen': 14, 'Projekt': 14, 'Ministerien': 13, 'Präsidenten': 13, 'Mittwoch': 13, 'Union': 13, 'Verhandlungen': 13, 'Sicherheit': 13, 'Tagen': 13, 'Grunde': 13, 'Regel': 13, 'Bereichen': 13, 'Koalitionsausschuss': 13, 'Probleme': 13, 'Wirtschaftsministerium': 13, 'Recht': 13, 'Wochenende': 13, 'USA': 13, 'Habeck': 13, 'Staat': 13, 'Technologien': 13, 'Technologie': 13, 'Panzer': 13, 'Leopard': 13, 'Montag': 12, 'Anschluss': 12, 'Dienstag': 12, 'Bundeskanzleramt': 12, 'Botschaft': 12, 'Kriegsverbrechen': 12, 'Aufklärung': 12, 'Infrastruktur': 12, 'Art': 12, 'Ressorts': 12, 'NATO': 12, 'Nationen': 12, 'Medien': 12, 'Geld': 12, 'Aufgabe': 12, 'Arbeitsmarkt': 12, 'Grund': 12, 'Lindner': 12, 'Lieferung': 12, 'Klimaschutz': 12, 'Verkehrsminister': 12, 'Donnerstag': 12, 'Ergänzung': 12, 'Bundespressekonferenz': 11, 'Sachen': 11, 'Sinne': 11, 'Steiner': 11, 'Cannabis': 11, 'Einschätzung': 11, 'Verkehrsministerium': 11, 'Japan': 11, 'Beschäftigten': 11, 'Elektromobilität': 11, 'Möglichkeiten': 11, 'Gesetzentwurf': 11, 'Finanzminister': 11, 'Programm': 11, 'Produkte': 11, 'Worte': 11, 'Grundlage': 11, 'Gebäude': 11, 'Sonntag': 11, 'Ressortabstimmung': 11, 'Subventionen': 11, 'Huawei': 11, 'Polen': 11}
# {'Fragen': 136, 'Deutschland': 119, 'Jahr': 75, 'Verfahren': 73, 'Gesetz': 71, 'Ort': 67, 'Bundeskanzler': 61, 'Lage': 58, 'Minister': 58, 'Ukraine': 57, 'Ihnen': 54, 'Dank': 53, 'Beispiel': 53, 'Kinder': 53, 'Kollegen': 50, 'Fall': 50, 'Nachfrage': 49, 'Stelle': 49, 'Sudan': 46, 'Ziel': 46, 'Menschen': 44, 'Cannabis': 44, 'Teil': 42, 'Länder': 40, 'Maßnahmen': 39, 'Zahlen': 39, 'Seite': 39, 'Gesetzentwurf': 38, 'Kabinett': 36, 'Weg': 36, 'Visa': 36, 'Moment': 35, 'Zahl': 35, 'Themen': 34, 'Milliarden': 33, 'Uhr': 32, 'Unternehmen': 31, 'Jahren': 31, 'Schwarzmarkt': 31, 'Ende': 30, 'Zeit': 30, 'Austausch': 30, 'Hoffmann': 29, 'Tag': 29, 'Rahmen': 29, 'Woche': 28, 'EU': 28, 'Regierung': 28, 'Liste': 27, 'Gespräche': 27, 'Verständnis': 27, 'April': 27, 'Förderung': 27, 'Säule': 27, 'Amt': 26, 'Russland': 26, 'Blick': 26, 'Vorschlag': 26, 'Kolleginnen': 25, 'Treffen': 25, 'Kontakt': 25, 'Bereich': 25, 'Möglichkeit': 25, 'Sofortprogramm': 25, 'Sicht': 25, 'Jahre': 25, 'Entwurf': 25, 'Gespräch': 24, 'Klimaschutz': 24, 'Land': 24, 'Kollege': 24, 'Haus': 24, 'Fehler': 24, 'Punkt': 24, 'Antibiotika': 24, 'Europa': 24, 'Montag': 23, 'Kanzler': 23, 'Entscheidung': 23, 'Partnern': 23, 'Reihe': 22, 'Mittwoch': 22, 'Auswärtigen': 22, 'Rolle': 22, 'Wochenende': 22, 'Lauterbach': 22, 'Kindergrundsicherung': 22, 'Diskussion': 21, 'Staaten': 21, 'Problem': 21, 'Zeitpunkt': 21, 'Stand': 21, 'Grundlage': 21, 'Produktion': 20, 'Botschaft': 20, 'Details': 20, 'Ministerium': 20, 'Aufsichtsrat': 20, 'Deutschen': 19, 'Gelegenheit': 19, 'Behörden': 19, 'Wagner': 19, 'Hintergrund': 19, 'Prüfung': 19, 'Ergebnis': 19, 'Kenntnis': 19, 'Gewalt': 19, 'Optionen': 19, 'Clubs': 19, 'Energie': 18, 'Berlin': 18, 'Zusammenarbeit': 18, 'Politik': 18, 'Leute': 18, 'Komplex': 18, 'Punkte': 18, 'Möglichkeiten': 18, 'Kosten': 18, 'Heizung': 18, 'Termin': 17, 'Unterstützung': 17, 'Frist': 17, 'Infrastruktur': 17, 'Raum': 17, 'Sicherheit': 17, 'Generation': 17, 'Mitarbeiter': 17, 'Büchner': 17, 'Jugendschutz': 17, 'Pflege': 17, 'Freitag': 16, 'Ministerien': 16, 'China': 16, 'Sache': 16, 'Anfang': 16, 'Regelungen': 16, 'Arzneimittel': 16, 'Entwicklung': 16, 'Koalitionsvertrag': 16, 'Bundeswehr': 16, 'Staatsangehörige': 16, 'Konsum': 16, 'Bundeskanzlers': 15, 'Wirtschaft': 15, 'Situation': 15, 'Zukunft': 15, 'Ziele': 15, 'Projekte': 15, 'Umsetzung': 15, 'Bericht': 15, 'Position': 15, 'Regelung': 15, 'Seiten': 15, 'Vorhaben': 15, 'Eckpunkte': 15, 'Sinn': 15, 'Form': 15, 'Besuch': 14, 'Anschluss': 14, 'Ländern': 14, 'Beginn': 14, 'Schutz': 14, 'Ebene': 14, 'Personen': 14, 'Antwort': 14, 'Anteil': 14, 'Richtung': 14, 'Vergangenheit': 14, 'Informationen': 14, 'Ihre': 14, 'Tagen': 14, 'Entlastung': 14, 'Zusammenhang': 14, 'Cannabispolitik': 14, 'Presse': 13, 'Sorge': 13, 'Äußerungen': 13, 'Nationen': 13, 'Staatsbürger': 13, 'Recht': 13, 'Wochen': 13, 'Regeln': 13, 'Befangenheit': 13, 'Bundestag': 13, 'Geld': 13, 'Einzelfall': 13, 'Prozent': 13, 'Auswärtige': 13, 'Bundesminister': 13, 'Ausland': 13, 'Gebäude': 13, 'Kritik': 13, 'Reform': 13, 'Vordergrund': 13, 'Jugendliche': 13, 'Pflegeversicherung': 13, 'Rede': 12, 'Mitglieder': 12, 'Hilfe': 12, 'Jahres': 12, 'Union': 12, 'Wissens': 12, 'Klima': 12, 'Koalition': 12, 'Mittel': 12, 'Abstimmung': 12, 'Person': 12, 'Aufgabe': 12, 'Probleme': 12, 'Wirtschaftsministerium': 12, 'Nachlieferung': 12, 'Rinke': 12, 'Evakuierung': 12, 'Finanzminister': 12, 'Euro': 12, 'Heizungen': 12, 'NATO': 12, 'Tunesien': 12, 'Einsatz': 11, 'Veranstaltung': 11, 'Mal': 11, 'Außenministerin': 11, 'Kommission': 11, 'Bevölkerung': 11, 'Region': 11, 'Berichte': 11, 'Tat': 11, 'Verkehrsministerium': 11, 'Zustimmung': 11, 'Wissing': 11, 'Ausbau': 11, 'Rechtslage': 11, 'Fällen': 11, 'Erklärung': 11, 'Autos': 11, 'Pläne': 11, 'System': 11, 'Kollegin': 11, 'EU-Kommission': 11, 'Vorgaben': 11, 'Visum': 11, 'Finanzministerium': 11, 'Haushalt': 11, 'Legalisierung': 11}
# {'Deutschland': 212, 'Fragen': 162, 'Bundeskanzler': 110, 'Ukraine': 89, 'Ihnen': 76, 'Länder': 70, 'Verfahren': 70, 'Jahr': 70, 'Menschen': 67, 'Minister': 66, 'Nachfrage': 63, 'Russland': 63, 'Fall': 61, 'Seite': 60, 'Kabinett': 56, 'Zeit': 56, 'Themen': 55, 'Situation': 53, 'Ländern': 52, 'Kanzler': 50, 'Regierung': 50, 'Stelle': 50, 'Maßnahmen': 50, 'Ort': 49, 'Sicht': 49, 'Mittwoch': 46, 'Hebestreit': 45, 'Dank': 45, 'Rahmen': 45, 'Gespräche': 44, 'Kollegen': 43, 'Treffen': 42, 'Zahl': 42, 'China': 42, 'Land': 41, 'Gespräch': 41, 'Position': 41, 'Ende': 40, 'Gesetz': 40, 'Amt': 39, 'Außenministerin': 39, 'Gesetzentwurf': 39, 'Blick': 38, 'Diskussion': 38, 'Teil': 38, 'Woche': 38, 'Beispiel': 38, 'Bund': 38, 'Staaten': 36, 'Moment': 35, 'Rolle': 35, 'Lage': 34, 'Zahlen': 34, 'Liste': 34, 'Weg': 33, 'Türkei': 33, 'Bundeskanzlers': 32, 'Pressekonferenz': 32, 'Bundestag': 31, 'Unterstützung': 31, 'Art': 31, 'Ministerin': 31, 'Bürger': 31, 'Kommunen': 31, 'Jahren': 30, 'Personen': 30, 'Prozess': 30, 'Präsident': 30, 'Entwicklung': 29, 'Kollege': 29, 'Uhr': 29, 'Schritt': 28, 'Schutz': 28, 'Bericht': 27, 'Sicherheit': 27, 'Antwort': 27, 'Gipfel': 27, 'Geld': 27, 'Einsatz': 26, 'Stand': 26, 'Behörden': 26, 'Details': 26, 'Euro': 26, 'Freitag': 26, 'Jung': 26, 'Regeln': 25, 'Europäischen': 25, 'Projekte': 25, 'Bereich': 25, 'G7': 25, 'Wahlen': 24, 'Interesse': 24, 'Wochen': 24, 'Wissens': 24, 'Termin': 24, 'Gesprächen': 24, 'Sprecher': 23, 'EU': 23, 'Lösung': 23, 'Zeitpunkt': 23, 'Punkt': 23, 'Sicherheitsbehörden': 23, 'Ministerium': 23, 'Mai': 23, 'Rede': 23, 'Jessen': 23, 'Recht': 22, 'Montag': 22, 'Hinweis': 22, 'Vergangenheit': 22, 'Entscheidung': 22, 'Tat': 22, 'Äußerungen': 22, 'Austausch': 22, 'Ministerien': 21, 'Tag': 21, 'Form': 21, 'Erkenntnisse': 21, 'Ziel': 21, 'Möglichkeit': 21, 'Person': 21, 'Zusammenarbeit': 21, 'Wahl': 21, 'Moldau': 21, 'Sommerpause': 21, 'Aufgabe': 20, 'Berlin': 20, 'Verständnis': 20, 'Arbeit': 20, 'BMI': 20, 'Polizei': 20, 'Presse': 20, 'Wort': 20, 'Sachen': 20, 'Milliarden': 20, 'Beteiligung': 19, 'Juni': 19, 'Auswärtigen': 19, 'Monaten': 19, 'Wochenende': 19, 'Kritik': 19, 'Wirtschaftsministerium': 19, 'Ergebnis': 19, 'Grund': 19, 'Europa': 19, 'Habeck': 19, 'Kommunikation': 19, 'BSI': 19, 'Industrie': 19, 'Branchen': 19, 'Informationen': 18, 'Präsenz': 18, 'Deutschen': 18, 'Afghanistan': 18, 'Einschätzung': 18, 'Büchner': 18, 'Republik': 18, 'Besuch': 18, 'Partner': 18, 'Berichte': 18, 'Medien': 18, 'Unternehmen': 18, 'Stellen': 18, 'Bundeswehr': 18, 'Projekt': 18, 'Vorschlag': 18, 'Seiten': 17, 'Zusammenhang': 17, 'Angriffskrieg': 17, 'Weise': 17, 'Ihre': 17, 'Scholz': 17, 'Parlament': 17, 'Millionen': 17, 'Ausbau': 17, 'Politik': 17, 'Haushalt': 17, 'Berichterstattung': 16, 'Präsidenten': 16, 'April': 16, 'Jahres': 16, 'Reihe': 16, 'Veranstaltung': 16, 'Außenminister': 16, 'Augenblick': 16, 'Problem': 16, 'Finanzministerium': 16, 'Kommission': 16, 'Außengrenzen': 16, 'Kategorie': 16, 'Kolleginnen': 15, 'Soldaten': 15, 'Umsetzung': 15, 'Frankreich': 15, 'Rinke': 15, 'Regelungen': 15, 'Bürgerinnen': 15, 'Jahre': 15, 'Kontakt': 15, 'Partei': 15, 'Zukunft': 15, 'Abkommen': 15, 'Asyl': 15, 'Hintergrund': 14, 'NATO': 14, 'Verantwortung': 14, 'Gebäude': 14, 'Sache': 14, 'Mal': 14, 'Staatspräsidenten': 14, 'Bewertung': 14, 'Meinung': 14, 'Sanktionen': 14, 'Ebene': 14, 'Kollegin': 14, 'Bedeutung': 14, 'Monate': 14, 'Inflation': 14, 'Anschluss': 14, 'Dinge': 14, 'Reise': 14, 'Ausdruck': 14, 'Punkte': 14, 'Migration': 14, 'Kinder': 14, 'Flüchtlinge': 14, 'Journalisten': 14, 'Abend': 14, 'Personal': 13, 'Gründe': 13, 'Planung': 13, 'Botschaft': 13, 'Haus': 13, 'Verhältnis': 13, 'Vorhaben': 13, 'Wirtschaft': 13, 'Einzelfall': 13, 'Generation': 13, 'Paket': 13, 'Satz': 13, 'Energie': 13, 'Abstimmung': 13, 'Raum': 13, 'Daten': 13, 'Bundes': 13, 'BMF': 13, 'Steiner': 13, 'Zeitplan': 13, 'Stichwort': 13, 'Krieg': 13, 'Bundespressekonferenz': 12, 'Staats-': 12, 'Kosovo': 12, 'Regierungschefs': 12, 'Regierung ...
# {'Fragen': 259, 'Deutschland': 183, 'Bundeskanzler': 128, 'Menschen': 105, 'Ukraine': 102, 'Ihnen': 101, 'Beispiel': 99, 'Jahr': 94, 'Fall': 93, 'Sicherheit': 89, 'Themen': 80, 'China': 80, 'Seite': 78, 'Dank': 76, 'Europa': 75, 'Blick': 69, 'Stelle': 66, 'Jahren': 66, 'Russland': 65, 'Teil': 64, 'Außenministerin': 63, 'Lage': 62, 'Gespräche': 60, 'Verfahren': 60, 'Zeit': 59, 'Nachfrage': 58, 'Regierung': 57, 'Kollegen': 56, 'Bereich': 56, 'AFD': 56, 'Ministerin': 55, 'Sicherheitsstrategie': 55, 'Land': 53, 'Länder': 53, 'Entscheidung': 52, 'Situation': 52, 'Uhr': 50, 'Strategie': 50, 'Wochen': 48, 'Personen': 48, 'Gesetz': 48, 'Rolle': 47, 'Pressekonferenz': 47, 'Welt': 46, 'Ziel': 46, 'Weg': 44, 'Gesprächen': 44, 'Staaten': 44, 'Ende': 43, 'Union': 43, 'Moment': 43, 'Minister': 43, 'Kanzler': 42, 'Bundeswehr': 42, 'Arbeit': 42, 'Woche': 41, 'Rahmen': 39, 'Unternehmen': 39, 'Büchner': 39, 'Ländern': 38, 'Ort': 38, 'Einschätzung': 38, 'Recht': 38, 'Europäischen': 38, 'Gewalt': 37, 'Gespräch': 36, 'Jahre': 36, 'EU': 36, 'Amt': 35, 'NATO': 35, 'Prozent': 35, 'Wochenende': 34, 'Polen': 34, 'Diskussion': 34, 'Tag': 33, 'Bericht': 33, 'System': 33, 'Schutz': 33, 'Entwicklung': 33, 'Demokratie': 33, 'Montag': 32, 'Erkenntnisse': 32, 'Zahlen': 32, 'Beratung': 32, 'Zahl': 31, 'Gesellschaft': 31, 'Staat': 31, 'Krieg': 31, 'Rechtsextremismus': 31, 'Liste': 30, 'Freitag': 29, 'Raum': 29, 'Leute': 29, 'Partnern': 29, 'Südafrika': 29, 'Termin': 28, 'Zusammenarbeit': 28, 'Milliarden': 28, 'Bundespolizei': 28, 'Bundeskanzlers': 27, 'Person': 27, 'Jessen': 27, 'Sicht': 27, 'Gefahr': 27, 'Position': 27, 'Geld': 27, 'Mittwoch': 26, 'Bundestag': 26, 'Maßnahmen': 26, 'Haushalt': 26, 'Bundespressekonferenz': 25, 'Punkt': 25, 'BMI': 25, 'Prozess': 25, 'Interesse': 25, 'Angriffskrieg': 25, 'Dinge': 25, 'Unterstützung': 24, 'Zukunft': 24, 'Informationen': 23, 'Sorge': 23, 'Partner': 23, 'Details': 23, 'Partei': 23, 'Reise': 23, 'Kolleginnen': 22, 'Treffen': 22, 'Zeitpunkt': 22, 'Litauen': 22, 'Stand': 22, 'Entwurf': 22, 'Gruppen': 22, 'Zusammenhang': 22, 'Debatte': 22, 'Verfassungsschutz': 22, 'Reform': 22, 'Hebestreit': 21, 'Erklärung': 21, 'Richtung': 21, 'Verständnis': 21, 'Anfang': 21, 'Sicherheitsbehörden': 21, 'Kabinett': 21, 'Politik': 21, 'Kinder': 21, 'Arzt': 21, 'Auswärtige': 20, 'Interessen': 20, 'Kenntnis': 20, 'Wirtschaft': 20, 'Tat': 20, 'Euro': 20, 'Hintergrund': 20, 'Scholz': 20, 'Möglichkeit': 20, 'Verfügung': 19, 'Mal': 19, 'Präsidenten': 19, 'Grundlage': 19, 'Austausch': 19, 'Meinung': 19, 'Komplex': 19, 'Türkei': 19, 'Besuch': 18, 'Tagen': 18, 'Monaten': 18, 'Behörden': 18, 'Juni': 18, 'Jung': 18, 'Ressorts': 18, 'Monate': 18, 'Konferenz': 18, 'Förderung': 18, 'Finanzminister': 18, 'Brigade': 18, 'Kommission': 18, 'Kollege': 18, 'Ministerien': 17, 'Frankreich': 17, 'Beginn': 17, 'Weise': 17, 'Ministerium': 17, 'Problem': 17, 'Bezug': 17, 'Dingen': 17, 'Antwort': 17, 'Art': 17, 'Präsident': 17, 'Bedingungen': 17, 'Ihre': 17, 'Prüfung': 17, 'Migration': 17, 'Intel': 17, 'Europäische': 17, 'Presse': 16, 'Nationen': 16, 'Augenblick': 16, 'Sommerpause': 16, 'Hinweis': 16, 'Mitte': 16, 'Hilfe': 16, 'Werbung': 16, 'Frauen': 16, 'Ergebnis': 16, 'Haus': 16, 'Stellen': 16, 'Kosten': 16, 'Einigung': 16, 'Israel': 16, 'Vergangenheit': 16, 'Gruppe': 16, 'Anschluss': 16, 'Grenze': 16, 'Termine': 15, 'Deutschen': 15, 'Landes': 15, 'Frieden': 15, 'Bürger': 15, 'EU-Kommission': 15, 'Teilen': 15, 'Kontakt': 15, 'Aufgabe': 15, 'Lösung': 15, 'Sinne': 15, 'Verteidigungsminister': 15, 'Juli': 15, 'Form': 15, 'Perspektive': 15, 'Berichterstattung': 15, 'USA': 15, 'Grund': 15, 'Reihe': 15, 'Bedrohung': 15, 'Vorhaben': 15, 'Straftaten': 15, 'Genfer': 15, 'Abstimmung': 14, 'Bewertung': 14, 'Vorgaben': 14, 'Verhandlungen': 14, 'Teile': 14, 'Deutschlands': 14, 'Regel': 14, 'Krise': 14, 'Klimaschutz': 14, 'Plan': 14, 'Praxis': 14, 'Wagner': 14, 'Familien': 14, 'Mittel': 14, 'Krieges': 14, 'Rinke': 14, 'Transformation': 14, 'Regelung': 14, 'Brasilien': 14, 'Pa ...
# {'Deutschland': 182, 'Fragen': 146, 'Jahr': 114, 'Millionen': 88, 'Beispiel': 84, 'Milliarden': 80, 'Regierung': 79, 'Bundeskanzler': 76, 'Menschen': 75, 'Jahren': 73, 'Euro': 70, 'Ihnen': 68, 'Minister': 66, 'Zeit': 63, 'Fall': 57, 'Stelle': 56, 'Dank': 54, 'Kollegen': 53, 'Ukraine': 53, 'Nachfrage': 50, 'Entscheidung': 50, 'Geld': 50, 'Ende': 49, 'Maßnahmen': 47, 'Seite': 47, 'Ort': 46, 'Land': 45, 'Jahre': 43, 'Bereich': 42, 'Haushalt': 42, 'Verfügung': 41, 'Lage': 40, 'Gespräche': 39, 'Länder': 38, 'Ziel': 38, 'Wasserstoff': 37, 'Weg': 35, 'Kabinett': 35, 'Zahl': 34, 'Patienten': 34, 'Antwort': 33, 'Woche': 32, 'Ministerin': 32, 'Rahmen': 32, 'Aufgabe': 32, 'Kinder': 32, 'Entwicklung': 31, 'Strategie': 30, 'Teil': 30, 'Zahlen': 30, 'Versorgungsforschung': 30, 'Problem': 29, 'Mittel': 29, 'Kolleginnen': 28, 'Dinge': 28, 'Europa': 28, 'Förderung': 28, 'Themen': 28, 'Klima': 28, 'Moment': 27, 'Haus': 27, 'Reise': 27, 'Ländern': 26, 'Raum': 26, 'Kanzler': 26, 'Politik': 26, 'China': 26, 'Bürger': 26, 'Situation': 25, 'AFD': 25, 'Wochen': 25, 'Prozent': 25, 'Frauen': 24, 'Kontakt': 24, 'Außenministerin': 24, 'EU': 24, 'Amt': 24, 'Bericht': 24, 'Ministerium': 24, 'Zukunft': 24, 'Sondervermögen': 24, 'Israel': 24, 'Unternehmen': 24, 'Kenntnis': 24, 'Forschung': 24, 'Sicherheit': 23, 'Punkt': 23, 'Zusammenhang': 23, 'Koalitionsvertrag': 23, 'Gesetz': 23, 'Art': 23, 'Versorgung': 23, 'Ministerien': 22, 'Wochenende': 22, 'Monaten': 22, 'Sicht': 22, 'Rolle': 22, 'Finanzierung': 22, 'Klimaschutz': 22, 'Hebestreit': 22, 'Weise': 22, 'Staaten': 21, 'Blick': 21, 'Vorschlag': 21, 'Erfolg': 21, 'Industrie': 21, 'Investitionen': 21, 'Russland': 21, 'Erkenntnisse': 20, 'USA': 20, 'Verfahren': 20, 'Wirtschaft': 20, 'Leute': 20, 'Zusammenarbeit': 20, 'Professor': 20, 'Medikamente': 20, 'Elterngeld': 20, 'Strukturen': 19, 'Verantwortung': 19, 'Position': 19, 'Gesellschaft': 19, 'Bedeutung': 19, 'Initiative': 19, 'Migration': 19, 'Ausgaben': 19, 'Ebene': 18, 'Hilfe': 18, 'Vorhaben': 18, 'Strom': 18, 'Bundestag': 18, 'Reihe': 18, 'Gespräch': 18, 'Bedarf': 18, 'Leopard': 18, 'Kindergrundsicherung': 18, 'Jung': 17, 'Fischer': 17, 'Präsident': 17, 'Projekte': 17, 'Eindruck': 17, 'Zeitpunkt': 17, 'Bürgerinnen': 17, 'Arbeit': 17, 'Betroffenen': 17, 'Volkswirtschaft': 17, 'Lauterbach': 17, 'Studien': 17, 'Union': 16, 'Auswärtige': 16, 'Richtung': 16, 'Sachen': 16, 'BMF': 16, 'Entwurf': 16, 'Grundlage': 16, 'Sorge': 16, 'Jahres': 16, 'Schritt': 16, 'Informationen': 16, 'Gesprächen': 16, 'Türkei': 16, 'Griechenland': 16, 'Welt': 16, 'Koalition': 16, 'Sofortprogramm': 16, 'Erkrankung': 16, 'Einschätzung': 15, 'Austausch': 15, 'Stand': 15, 'Unterstützung': 15, 'Mitte': 15, 'Tat': 15, 'Montag': 15, 'Kollege': 15, 'Augenblick': 15, 'Kollegin': 15, 'Abstimmung': 15, 'Konsequenzen': 15, 'Krieg': 15, 'Bundeswehr': 14, 'Botschaft': 14, 'Ihre': 14, 'Beitrag': 14, 'Antrag': 14, 'Verständnis': 14, 'Verhandlungen': 14, 'Polizei': 14, 'Bundeskanzlers': 14, 'Gesetzentwurf': 14, 'Bundeskabinett': 14, 'Europäischen': 14, 'Ziele': 14, 'Möglichkeiten': 14, 'Sache': 14, 'Ressorts': 14, 'Waffen': 14, 'Ärzte': 14, 'Behandlung': 14, 'Schuldenbremse': 14, 'Personen': 13, 'Ergebnis': 13, 'Tagen': 13, 'Grunde': 13, 'Tag': 13, 'Verkehrsministerium': 13, 'Vorgaben': 13, 'Sinne': 13, 'Wort': 13, 'Innovation': 13, 'Anträge': 13, 'Debatte': 13, 'Indien': 13, 'Mittwoch': 13, 'Lindner': 13, 'Gipfel': 13, 'Tisch': 13, 'Personal': 12, 'Soldaten': 12, 'Äußerungen': 12, 'Partnern': 12, 'Tage': 12, 'Folge': 12, 'Planung': 12, 'Abteilungsleiter': 12, 'Projektträger': 12, 'Stellen': 12, 'Jessen': 12, 'Grund': 12, 'Prüfung': 12, 'BMI': 12, 'Hand': 12, 'Risiko': 12, 'Signal': 12, 'Bürgern': 12, 'Bundesminister': 12, 'Programm': 12, 'Probleme': 12, 'Sommer': 12, 'Ergebnisse': 12, 'NATO': 12, 'Grundsicherung': 12, 'Bundeshaushalt': 12, 'Finanzplanung': 12, 'Niger': 11, 'Präsidenten': 11, 'Forderungen': 11, 'Berichterstattung': 11, 'Interesse': 11, 'Tatsache': 11, 'Meinung': 11, 'Haltung': 11, 'Au ...
# {'Deutschland': 75, 'Fragen': 73, 'Maßnahmen': 73, 'Jahr': 62, 'Fall': 52, 'Beispiel': 46, 'Menschen': 44, 'Regierung': 40, 'Millionen': 40, 'Ihnen': 36, 'Gesetz': 36, 'Minister': 35, 'Ende': 35, 'Ort': 33, 'Zahlen': 33, 'Bundeskanzler': 32, 'Land': 32, 'Dank': 31, 'Nachfrage': 30, 'Rahmen': 30, 'Kollegen': 28, 'Verfahren': 27, 'Bereich': 27, 'Lücke': 27, 'Stelle': 26, 'Ziel': 26, 'Zeit': 25, 'Jahren': 25, 'Lage': 24, 'Geld': 24, 'Verfügung': 24, 'Moment': 24, 'Teil': 23, 'Weg': 23, 'Euro': 23, 'Themen': 22, 'Umsetzung': 22, 'Dingen': 22, 'Seite': 21, 'Zahl': 21, 'Problem': 21, 'Büchner': 20, 'Ländern': 20, 'Bundespolizei': 20, 'Bundeswehr': 20, 'Verkehr': 20, 'Gutachten': 20, 'Gebäude': 20, 'Klimaschutzprogramm': 20, 'Sicht': 19, 'Mittel': 19, 'Entwicklung': 19, 'Ziele': 19, 'Kabinett': 18, 'Kinder': 18, 'Klimaschutz': 18, 'Ministerin': 18, 'Staatsbürgerschaft': 18, 'Ukraine': 17, 'Jahre': 17, 'Prüfung': 17, 'Novelle': 17, 'Gesetzentwurf': 16, 'Kanzler': 16, 'Grenze': 16, 'Unterstützung': 16, 'Zusammenhang': 16, 'Bürokratie': 16, 'Länder': 16, 'Programm': 16, 'Behörden': 16, 'Blick': 15, 'Milliarden': 15, 'Gespräche': 15, 'Ressorts': 15, 'Kritik': 15, 'Stand': 15, 'Bericht': 15, 'Unternehmen': 15, 'Uhr': 15, 'Einbürgerung': 15, 'Meseberg': 14, 'Bundeskanzlers': 14, 'Bund': 14, 'Prozent': 14, 'Wirtschaft': 14, 'Haltung': 14, 'Fachkräfte': 14, 'Bundes': 14, 'Diskussion': 14, 'Gesellschaft': 14, 'Haushalt': 14, 'Punkt': 14, 'Staatsangehörigkeit': 14, 'BMI': 13, 'Tat': 13, 'Wochenende': 13, 'Kenntnis': 13, 'Regelung': 13, 'Bezug': 13, 'Kommunen': 13, 'Entwurf': 13, 'Woche': 13, 'Klima': 13, 'Finanzierung': 13, 'Details': 13, 'Tonnen': 13, 'Berechnung': 13, 'Gesamtkonzept': 13, 'Entscheidung': 12, 'Richtung': 12, 'Prozess': 12, 'Einschätzung': 12, 'Reform': 12, 'Erkenntnisse': 12, 'Voraussetzungen': 12, 'Zukunft': 12, 'Zuständigkeit': 12, 'Montag': 11, 'Pressekonferenz': 11, 'Sinne': 11, 'Wirtschaftsministerium': 11, 'Anfang': 11, 'Kosten': 11, 'Bereichen': 11, 'Maßnahme': 11, 'Vorgaben': 11, 'Staaten': 11, 'Sektoren': 11, 'Bevölkerung': 11, 'Gesetzes': 11, 'Bundestag': 11, 'Transformation': 11, 'Staatsangehörigkeitsrecht': 11, 'Kolleginnen': 11, 'Berichte': 11, 'Hilfe': 11, 'Tag': 11}
# ...
# {'Deutschland': 38, 'Also,': 38, 'Bundeskanzler': 37, 'Israel': 37, 'Ihnen': 29, 'Gaza': 25, 'Der': 23, 'Ist': 23, 'Fragen': 23, 'Aber': 23, 'Wie': 22, 'Ende': 20, 'Lage': 20, 'Da': 20, 'Ziel': 19, 'Thema.': 18, 'Bereich': 17, 'Tagen': 17, 'Ukraine': 17, 'Stelle': 17, 'Kabinett': 17, 'Zahlen': 16, 'Frage,': 16, 'Dank.': 15, 'Vielen': 15, 'Amt': 15, 'Entscheidung': 15, 'Äh,': 15, 'Hamas': 15, 'Regierung': 14, 'Austausch': 14, 'Blick': 14, 'Gesetz': 14, 'Was': 14, 'Anfang': 12, 'Nachfrage': 12, 'Kollegen': 12, 'Journalisten': 12, 'Koalition': 11, 'Maßnahmen': 11, 'Wochenende': 11, 'Haltung': 11, 'Sicht': 11, 'Ja.': 11, 'Menschen': 11, 'Beziehungen': 11}
# {'Deutschland': 192, 'Ihnen': 141, 'Also,': 139, 'Fragen': 133, 'Bundeskanzler': 117, 'Wie': 111, 'Da': 98, 'Ziel': 94, 'Der': 92, 'Aber': 88, 'Äh,': 86, 'Frage,': 73, 'Woche': 72, 'Regierung': 71, 'Nachfrage': 70, 'Jahr': 70, 'Israel': 67, 'Gespräche': 66, 'Ist': 65, 'Thema.': 65, 'Milliarden': 61, 'Stelle': 60, 'NATO': 60, 'Ende': 58, 'Position': 55, 'Unternehmen': 55, 'Minister': 54, 'Zeit': 53, 'Können': 53, 'Danke.': 52, 'Maßnahmen': 52, 'Themen': 51, 'Frage.': 51, 'Fall': 50, 'Dank.': 50, 'Teil': 50, 'Ministerin': 50, 'Jung,': 49, 'Wenn': 48, 'Drohnen': 47, 'Ja.': 47, 'Menschen': 47, 'Was': 46, 'Bereich': 46, 'Kanzler': 46, 'Euro': 45, 'Austausch': 44, 'Jetzt': 44, 'Land': 44, 'Außenminister': 44, 'Jahren': 44, 'Ukraine': 44, 'Polen': 44, 'Rahmen': 43, 'Seite': 43, 'USA': 43, 'Vielen': 41, 'In': 40, 'Koalitionsvertrag': 40, 'Deswegen': 39, 'Russland': 39, 'Zahlen': 39, 'Kollegen': 39, 'Vielleicht': 38, 'Sicht': 38, 'Lage': 37, 'Afghanistan': 36, 'EU': 36, 'Genau.': 36, 'Gibt': 35, 'Personen': 35, 'Weitere': 35, 'Auch': 34, 'Unterstützung': 34, 'Jessen,': 34, 'Blick': 34, 'Ort': 33, 'Kenntnis': 32, 'Äußerung': 32, 'Mittel': 32, 'Treffen': 32, 'Wochen': 31, 'Bundeskanzlers': 31, 'Weg': 31, 'Amt': 30, 'Antwort': 30, 'Entscheidung': 30, 'Dazu': 30, 'Haltung': 30, 'Europäischen': 30, 'Prozess': 30, 'Nachfrage,': 30, 'Frankreich': 29, 'Zusammenhang': 29, 'Regierungssprecher': 28, 'Bundesregierung,': 28, 'Eine': 28, 'Gaza': 28, 'Verfahren': 28, 'Liste': 28, 'Thema,': 28, 'Wochenende': 27, 'Länder': 27, 'Zahl': 27, 'Termin': 27, 'Am': 27, 'Uhr': 27, 'Interesse': 27, 'Freitag': 26, 'Bezug': 26, 'Zusammenarbeit': 26, 'März': 26, 'Haushalt': 26, 'Kommission': 26, 'Pakistan': 26, 'Gesprächen': 25, 'Insofern': 25, 'Rinke': 25, 'Einschätzung': 25, 'Monaten': 25, 'Richtung': 25, 'August': 25, 'Staaten': 25, 'Ein': 25, 'New': 25, 'Politik': 25, 'Kabinett': 24, 'Sicherheit': 24, 'Einsatz': 24, 'Vergangenheit': 24, 'Danke': 24, 'Im': 24, 'Damit': 24, 'Sanktionen': 24, 'Bundesregierung.': 24, 'Staat': 24, 'Schritte': 24, 'Rinke.': 24, 'Wirtschaft': 24, 'Stand': 24, 'Form': 23, 'Partner': 23, 'Gespräch': 23, 'Zukunft': 23, 'Diese': 23, 'Montag': 23, 'Geld': 23, 'Gesetz': 22, 'Raum': 22, 'Präsidenten': 22, 'Abend': 22, 'Entwicklung': 22, 'China': 22, 'Dank': 21, 'Brief': 21, 'Rinke,': 21, 'Umsetzung': 21, 'Tag': 21, 'Jahre': 21, 'Sie,': 21, 'Vorschlag': 21, 'Punkt': 21, 'Berlin': 21, 'Cornelius,': 21, 'Herbst': 20, 'Abstimmung': 20, 'Fragen.': 20, 'Nein,': 20, 'Zeitpunkt': 20, 'Informationen': 20, 'Personen,': 20, 'Kolleginnen': 20, 'Konflikt': 20, 'Investitionen': 20, 'Reform': 20, 'Reformen': 20, 'Welt': 20, 'Hille,': 19, 'Details': 19, 'Na': 19, 'Ebene': 19, 'Moment': 19, 'Nachfrage.': 19, 'Ministerium': 19, 'Projekt': 19, 'System': 19, 'Rede': 19, 'Bahn': 19, 'UN': 19, 'Dingen': 18, 'Bundeswehr': 18, 'Äußerungen': 18, 'BMI': 18, 'Erkenntnisse': 18, 'September': 18, 'Vorgehen': 18, 'Oktober': 18, 'Deshalb': 18, 'Frist': 18, 'Aussagen': 18, 'Aussage': 18, 'Infrastruktur': 18, 'Situation': 18, 'Entscheidungen': 18, 'Hille': 17, 'Sprecher': 17, 'Kontakt': 17, 'Meine': 17, 'Prüfung': 17, 'Wer': 17, 'Millionen': 17, 'So': 17, 'York': 17, 'Energien': 17, 'Für': 17, 'Ergebnis': 17, 'Cornelius': 17, 'Tagen': 17, 'Ländern': 16, 'Gesetzentwurf': 16, 'Kosten': 16, 'Partnern': 16, 'Bund': 16, 'Reaktion': 16, 'Kollege': 16, 'Europa': 16, 'Mittwoch': 16, 'Regierungspressekonferenz': 16, 'Arbeit': 16, 'Fechner,': 16, 'Koalition': 16, "Gibt's": 16, 'Möglichkeit': 16, 'Stellung': 16, 'Ministerien': 15, 'Stichwort': 15, 'Bundestag': 15, 'Staatsbürger': 15, 'Waffenstillstand': 15, 'Mal': 15, 'Union': 15, 'Wort': 15, 'Ausgaben': 15, 'Krieg': 15, 'Noch': 15, 'Entschuldigung,': 15, 'Vorschläge': 15, 'Debatte': 15, 'Vorhaben': 15, 'Kann': 14, 'Ihrer': 14, 'Beitrag': 14, 'Auftrag': 14, 'Deutschland.': 14, 'Weise': 14, 'Kabul': 14, 'Schritt': 14, 'Natürlich': 14, 'Präsident': 14, 'Lösung': 14, 'Verfügung': 14, 'Deutsche': 14, 'Art': 14, 'Deutschlands': 14, 'Reise ...
# {'Deutschland': 209, 'Fragen': 163, 'Also,': 154, 'Ihnen': 136, 'Bundeskanzler': 131, 'Da': 114, 'Wie': 105, 'Menschen': 105, 'Der': 103, 'Aber': 79, 'Ende': 77, 'Ort': 75, 'Woche': 75, 'Minister': 73, 'Äh,': 72, 'Stelle': 72, 'Dank.': 68, 'Genau.': 68, 'Nachfrage': 67, 'Kanzler': 67, 'Lage': 67, 'Gibt': 66, 'Frage,': 64, 'Reise': 64, 'Vielen': 61, 'Rahmen': 59, 'Jahr': 59, 'Was': 59, 'Verfahren': 59, 'Gespräche': 58, 'Ist': 57, 'Themen': 57, 'Ja.': 55, 'Frage.': 55, 'Zeit': 54, 'Seite': 54, 'Jetzt': 53, 'Blick': 51, 'Austausch': 51, 'Sicherheit': 50, 'Gaza': 50, 'Fall': 49, 'Türkei': 49, 'Danke.': 48, 'Ministerin': 48, 'Teil': 48, 'Thema.': 48, 'Treffen': 47, 'Bundeswehr': 47, 'Außenminister': 46, 'Können': 44, 'Bereich': 44, 'NATO': 44, 'Ziel': 43, 'Tat': 43, 'Wenn': 43, 'Gespräch': 43, 'Regierung': 42, 'Weg': 41, 'Deswegen': 41, 'Position': 41, 'Ukraine': 41, 'EU': 40, 'Maßnahmen': 40, 'BMI': 40, 'So,': 38, 'Gut,': 38, 'In': 37, 'Mittwoch': 36, 'Kenntnis': 36, 'Unternehmen': 36, 'Situation': 36, 'Dazu': 36, 'Kollegen': 35, 'Stand': 35, 'Prozess': 35, 'Im': 34, 'Jahren': 34, 'Russland': 34, 'Land': 34, 'Kabinett': 33, 'Details': 33, 'Rolle': 33, 'China': 33, 'Antwort': 32, 'Schritt': 32, 'Amt': 32, 'Auch': 32, 'Vielleicht': 32, 'Personen': 32, 'Jahre': 31, 'Am': 31, 'Wirtschaft': 31, 'Israel': 31, 'Moment': 31, 'Hilfe': 31, 'Danke': 30, 'Er': 30, 'Gesprächen': 30, 'Eine': 30, 'Sicht': 30, 'Zahlen': 30, 'Uhr': 29, 'Ebene': 29, 'Jung,': 29, 'Zahl': 29, 'Menschen,': 29, 'Ost': 29, 'Regierungssprecher': 28, 'Zusammenarbeit': 28, 'Nachfrage,': 28, 'Region': 28, 'Weitere': 28, 'Tag': 28, 'Zukunft': 28, 'Trump': 27, 'Insofern': 27, 'Kommunen': 27, 'Haltung': 27, 'Entwicklung': 26, 'Dinge': 26, 'Partnern': 26, 'Okay,': 26, 'Dank': 25, 'Raum': 25, 'Bundesregierung,': 25, 'Tagen': 25, 'Äußerung': 25, 'Entscheidung': 25, 'Unterstützung': 25, 'Oktober': 25, 'Drohnen': 25, 'Bereichen': 24, 'Vergangenheit': 24, 'Europa': 24, 'Länder': 24, 'Frankreich': 24, 'Millionen': 24, 'Zeitpunkt': 24, 'Freitag': 24, 'Thema,': 23, 'Themen,': 23, 'Vorschlag': 23, 'Beitrag': 23, 'Europäischen': 23, 'USA': 23, 'Umsetzung': 23, 'Reihe': 23, 'Pressekonferenz': 22, 'Bitte': 22, 'So': 22, 'Veränderungen': 22, 'Dingen': 22, 'Unterschiede': 22, 'Regionen': 22, 'Kollege': 21, 'Kanzlers': 21, 'Meer,': 21, 'Jessen,': 21, 'Fragen.': 21, 'Präsident': 21, 'Aussage': 21, 'Entschuldigung,': 21, 'Wiederaufbau': 21, 'Union': 21, 'Kolleginnen': 20, 'Schritte': 20, 'Form': 20, 'März': 20, 'Abstimmung': 20, 'Gesetz': 20, 'Punkt': 20, 'Partner': 20, 'System': 20, 'Ostdeutschland': 20, 'Bundeskanzlers': 19, 'Euro': 19, 'Nachfrage.': 19, 'Möglichkeit': 19, 'Sie,': 19, 'Ländern': 19, 'Waffenstillstand': 19, 'Staaten': 19, 'Kollegin': 19, 'Cornelius': 19, 'Montag': 18, 'Anschluss': 18, 'Zum': 18, 'Termin': 18, 'Hat': 18, 'Steiner': 18, 'Meer': 18, 'Lösung': 18, 'Zu': 18, 'Frieden': 18, 'Interesse': 18, 'Diskussion': 18, 'Arbeit': 18, 'Leute': 18, 'EU-Kommission': 18, 'Jahres': 17, 'Termine': 17, 'Dort': 17, 'Rede': 17, 'Richtung': 17, 'Liste': 17, 'Äußerungen': 17, 'Informationen': 17, 'Daten': 17, 'Nein,': 17, 'Detail': 17, 'Kommunikation': 17, 'Cornelius.': 17, 'Gesellschaft': 17, 'Diese': 16, 'Schutz': 16, 'Wochen': 16, 'Tage': 16, 'Wird': 16, 'Bedeutung': 16, 'Koalitionsvertrag': 16, 'Ausland': 16, 'Aussagen': 16, 'Einsatz': 16, "Gibt's": 16, 'Hamas': 16, 'Beteiligung': 16, 'Grunde': 16, 'Bericht': 16, 'Cornelius,': 16, 'Vorfeld': 15, 'Möglichkeiten': 15, 'Steiner,': 15, 'Herausforderungen': 15, 'Kontext': 15, 'Genau,': 15, 'Vorgehen': 15, 'Jung': 15, 'Geiseln': 15, 'Liegenschaften': 15, 'Einschätzung': 15, 'Reisen': 15, 'Wochenende': 15, 'F35': 15, 'Staatsangehörigkeit': 15, 'Sprecher': 14, 'Woche.': 14, 'Schwerpunkt': 14, 'Vorschläge': 14, 'Anfang': 14, 'Präsidenten': 14, 'Europäische': 14, 'Sind': 14, 'Monate': 14, 'Hintergrund': 14, 'Versorgung': 14, 'Verfügung': 14, 'Problem': 14, 'Migration': 14, 'Ministerien': 14, 'Rinke,': 14, 'Rinke': 14, 'Behörden': 14, 'Deutschen ...
# {'Bundeskanzler': 103, 'Deutschland': 101, 'Fragen': 94, 'Ihnen': 81, 'Wie': 74, 'Also,': 71, 'Da': 67, 'Der': 65, 'Aber': 61, 'Ukraine': 58, 'Äh,': 54, 'Fall': 51, 'Genau.': 49, 'Dank.': 48, 'Thema.': 46, 'Ende': 46, 'Frage.': 44, 'Woche': 43, 'Jahr': 40, 'Frage,': 40, 'Themen': 40, 'Minister': 40, 'Menschen': 39, 'Ist': 36, 'Nachfrage': 36, 'Ziel': 35, 'Gibt': 33, 'Gespräche': 33, 'Verfahren': 32, 'Vielen': 32, 'Lage': 32, 'Danke.': 31, 'Kanzler': 31, 'Können': 31, 'Seite': 29, 'Weimer': 29, 'Weitere': 29, 'Syrien': 29, 'Ministerin': 28, 'Entscheidung': 28, 'Dazu': 28, 'Was': 28, 'Rahmen': 28, 'Personen': 28, 'Stelle': 28, 'Ort': 28, 'Regierung': 28, 'Ja.': 27, 'Jessen,': 27, 'Sicht': 27, 'Kabinett': 26, 'Außenminister': 26, 'Deswegen': 26, 'Amt': 25, 'Person': 25, 'So,': 24, 'Wochen': 24, 'Länder': 24, 'Austausch': 24, 'Position': 24, 'Kenntnis': 23, 'Europa': 23, 'Unterstützung': 23, 'China': 23, 'Moment': 23, 'Cornelius': 23, 'Regierungssprecher': 22, 'Wenn': 22, 'Prozess': 22, 'Gespräch': 22, 'EU': 22, 'Bundeswehr': 22, 'Termin': 22, 'Teilnahme': 22, 'Teil': 22, 'Situation': 22, 'Maßnahmen': 21, 'Weg': 21, 'Treffen': 21, 'Unternehmen': 21, 'Rede': 21, 'Nein,': 20, 'Jetzt': 20, 'G20': 20, 'Gesetz': 20, 'Verfügung': 20, 'Brasilien': 20, 'Danke': 19, 'Rolle': 19, 'Er': 19, 'Uhr': 19, 'Bereich': 19, 'Bundespräsident': 19, 'Freitag': 18, 'Gipfel': 18, 'Stand': 18, 'Bundesregierung,': 18, 'Souveränität': 18, 'Im': 18, 'Debatte': 18, 'Gut,': 17, 'Vielleicht': 17, 'Zusammenhang': 17, 'Union': 17, 'Sicherheit': 17, 'BMI': 17, 'Geld': 17, 'Zusammenarbeit': 17, 'System': 17, 'Land': 17, 'Nachfrage,': 17, 'Euro': 17, 'Rückführung': 17, 'Wochenende': 16, 'Dank': 16, 'Zeit': 16, 'Punkte': 16, 'Kollege': 16, 'Koalition': 16, 'Entschuldigung,': 16, 'Europäischen': 16, 'Punkt': 16, 'Interessen': 16, 'Fall.': 16, 'Art': 16, 'Blick': 16, 'Israel': 16, 'November': 16, 'Bundeskanzlers': 16, 'Grunde': 16, 'Cornelius,': 16, 'Sprecher': 15, 'Entscheidungen': 15, 'Dinge': 15, 'Bezug': 15, 'Sie,': 15, 'Hat': 15, 'Tag': 15, 'Arbeit': 15, 'Media': 15, 'Group': 15, 'Eine': 15, 'Reise': 15, 'Berlin': 15, 'Interesse': 15, 'Fälle': 15, 'Diskussion': 15, 'Liste': 15, 'Vorschläge': 14, 'Anschluss': 14, 'Jahres': 14, 'Rentenkommission': 14, 'Kommission': 14, 'Zukunft': 14, 'Worte': 14, 'Okay,': 14, 'Staatsminister': 14, 'USA': 14, 'Details': 14, 'Rückkehr': 14, 'Bericht': 14, 'Milliarden': 14, 'So': 13, 'Okay.': 13, 'Jahren': 13, 'Beitrag': 13, 'Gesetzentwurf': 13, 'Tagen': 13, 'Auch': 13, 'Bundeskabinett': 13, 'Kollegen': 13, 'Termine': 13, 'Zahlen': 13, 'Nachfrage.': 13, 'Jessen': 13, 'Ländern': 13, 'Frieden': 13, 'Einschätzung': 13, 'Hilfe': 13, 'Nee,': 12, 'Rentensystem': 12, 'Warum': 12, 'Inhalte': 12, 'Weise': 12, 'Zahl': 12, 'Mitglieder': 12, 'Grundlage': 12, 'Raum': 12, 'Möglichkeit': 12, 'Berichte': 12, 'Jahre': 12, 'Vertreter': 12, 'Schutz': 12, 'Sachen': 12, 'Äußerung': 12, 'Insofern': 12, 'Richtung': 12, 'Wirtschaftsministerium': 12, 'Afghanistan': 12, 'Jung,': 12, 'Haben': 12, 'Bild': 12, 'Diese': 11, 'In': 11, 'Deutschland,': 11, 'Form': 11, 'Hille,': 11, 'Zeitpunkt': 11, 'Vorschlag': 11, 'Mittwoch': 11, 'Sinne': 11, 'Kriterien': 11, 'Politik': 11, 'Veranstaltung': 11, "I'm": 11, 'Ebene': 11, 'Innenministerium': 11, 'Mittel': 11, 'Jung': 11, 'Bedeutung': 11, 'Stahlindustrie': 11}
